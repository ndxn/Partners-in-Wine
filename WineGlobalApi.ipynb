# %%
import urllib
import json
import pandas as pd

# Import the API key.
from config import wine_api_key

# %%
headers = {
    'accept': 'application/json',
    'authorization': wine_api_key
    }
req = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=red&limit=2000&country=France', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)

# %%
res = urllib.request.urlopen(req).read().decode()
obj = json.loads(res)

# %%
obj
# Out:
# {'count': 19987,
#  'next': 'https://api.globalwinescore.com/globalwinescores/latest/?color=red&country=France&limit=2000&offset=2000',
#  'previous': None,
#  'results': [{'wine': 'Chateau Lafleur, Pomerol',
#    'wine_id': 37920,
#    'wine_slug': 'chateau-lafleur-pomerol',
#    'appellation': 'Pomerol',
#    'appellation_slug': 'pomerol',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': None,
#    'vintage': '2017',
#    'date': '2020-12-01',
#    'is_primeurs': False,
#    'score': 97.76,
#    'confidence_index': 'A',
#    'journalist_count': 13,
#    'lwin': 1011902,
#    'lwin_11': 10119022017},
#   {'wine': 'Vieux Chateau Certan, Pomerol',
#    'wine_id': 147420,
#    'wine_slug': 'vieux-chateau-certan-pomerol',
#    'appellation': 'Pomerol',
#    'appellation_slug': 'pomerol',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': None,
# ...

# %%
wine_df = pd.DataFrame.from_dict(obj['results'], orient='columns')
wine_df
# Out:
#                                         wine  wine_id  \
# 0                   Chateau Lafleur, Pomerol    37920
# 1              Vieux Chateau Certan, Pomerol   147420
# 2                            Petrus, Pomerol   114959
# 3     Chateau Pavie, Saint Emilion Grand Cru    39797
# 4           Chateau L'Eglise Clinet, Pomerol    36905
# ...                                      ...      ...
# 1995                 Chateau Palmer, Margaux    39755
# 1996           Chateau Lynch Bages, Pauillac    38918
# 1997           Chateau Lynch Bages, Pauillac    38918
# 1998           Chateau Lynch Bages, Pauillac    38918
# 1999                 Chateau Palmer, Margaux    39755
#
#                                   wine_slug              appellation  \
# 0                   chateau-lafleur-pomerol                  Pomerol
# 1              vieux-chateau-certan-pomerol                  Pomerol
# 2                            petrus-pomerol                  Pomerol
# ...

# %%
wine_df.dtypes
# Out:
# wine                 object
# wine_id               int64
# wine_slug            object
# appellation          object
# appellation_slug     object
# color                object
# wine_type            object
# regions              object
# country              object
# classification       object
# vintage              object
# date                 object
# is_primeurs            bool
# score               float64
# confidence_index     object
# journalist_count      int64
# lwin                float64
# lwin_11             float64
# dtype: object

# %%
headers = {
    'accept': 'application/json',
    'authorization': wine_api_key
    }
req = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=red&limit=2000&country=Australia', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)

# %%
res = urllib.request.urlopen(req).read().decode()
obj_Austraila = json.loads(res)
obj_Austraila
# Out:
# {'count': 692,
#  'next': None,
#  'previous': None,
#  'results': [{'wine': 'Jim Barry, The Armagh Shiraz, Clare Valley',
#    'wine_id': 88727,
#    'wine_slug': 'jim-barry-the-armagh-shiraz-clare-valley',
#    'appellation': 'Clare Valley',
#    'appellation_slug': 'clare-valley',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Australia'],
#    'country': 'Australia',
#    'classification': None,
#    'vintage': '2012',
#    'date': '2020-06-11',
#    'is_primeurs': False,
#    'score': 97.13,
#    'confidence_index': 'A',
#    'journalist_count': 4,
#    'lwin': 1000971,
#    'lwin_11': 10009712012},
#   {'wine': 'Jim Barry, The Armagh Shiraz, Clare Valley',
#    'wine_id': 88727,
#    'wine_slug': 'jim-barry-the-armagh-shiraz-clare-valley',
#    'appellation': 'Clare Valley',
#    'appellation_slug': 'clare-valley',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Australia'],
#    'country': 'Australia',
#    'classification': None,
# ...

# %%
wine_Australia_df = pd.DataFrame.from_dict(obj_Austraila['results'], orient='columns')
wine_Australia_df
# Out:
#                                                   wine  wine_id  \
# 0           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 1           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 2           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 3           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 4           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# ..                                                 ...      ...
# 687   Penfolds, Bin 28 Shiraz Kalimna, South Australia   148510
# 688                        Grosset, Gaia, Clare Valley    80663
# 689  Greenock Creek Vineyards & Cellars, Cabernet S...    80401
# 690      D'Arenberg, The Dead Arm Shiraz, Mclaren Vale    48121
# 691                 Penfolds, Bin 707, South Australia   148664
#
#                                              wine_slug      appellation  \
# 0             jim-barry-the-armagh-shiraz-clare-valley     Clare Valley
# ...

# %%
headers = {
    'accept': 'application/json',
    'authorization': wine_api_key
    }
req = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=red&limit=2000&country=South%20Africa', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)

# %%
res = urllib.request.urlopen(req).read().decode()
obj_SouthAfrica = json.loads(res)
obj_SouthAfrica
# Out:
# {'count': 99,
#  'next': None,
#  'previous': None,
#  'results': [{'wine': 'De Toren, Fusion V, Stellenbosch',
#    'wine_id': 150591,
#    'wine_slug': 'de-toren-fusion-v-stellenbosch',
#    'appellation': 'Stellenbosch',
#    'appellation_slug': 'stellenbosch',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Coastal Region'],
#    'country': 'South Africa',
#    'classification': None,
#    'vintage': '2015',
#    'date': '2018-06-30',
#    'is_primeurs': False,
#    'score': 91.8,
#    'confidence_index': 'B',
#    'journalist_count': 3,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Raats Family Wines, Jasper Red, Stellenbosch',
#    'wine_id': 150672,
#    'wine_slug': 'raats-family-wines-jasper-red-stellenbosch',
#    'appellation': 'Stellenbosch',
#    'appellation_slug': 'stellenbosch',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Coastal Region'],
#    'country': 'South Africa',
#    'classification': None,
#    'vintage': '2015',
# ...

# %%
wine_SouthAfrica_df = pd.DataFrame.from_dict(obj_Austraila['results'], orient='columns')
wine_SouthAfrica_df
# Out:
#                                                   wine  wine_id  \
# 0           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 1           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 2           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 3           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# 4           Jim Barry, The Armagh Shiraz, Clare Valley    88727
# ..                                                 ...      ...
# 687   Penfolds, Bin 28 Shiraz Kalimna, South Australia   148510
# 688                        Grosset, Gaia, Clare Valley    80663
# 689  Greenock Creek Vineyards & Cellars, Cabernet S...    80401
# 690      D'Arenberg, The Dead Arm Shiraz, Mclaren Vale    48121
# 691                 Penfolds, Bin 707, South Australia   148664
#
#                                              wine_slug      appellation  \
# 0             jim-barry-the-armagh-shiraz-clare-valley     Clare Valley
# ...

# %%
# Request data
headers = {
    'accept': 'application/json',
    'authorization': wine_api_key
    }
req = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=red&limit=2000&country=Italy', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)
res = urllib.request.urlopen(req).read().decode()
obj_Italy = json.loads(res)
obj_Italy
# Out:
# {'count': 1631,
#  'next': None,
#  'previous': None,
#  'results': [{'wine': 'Biondi Santi Tenuta Greppo, Riserva, Brunello Di Montalcino',
#    'wine_id': 12050,
#    'wine_slug': 'biondi-santi-tenuta-greppo-riserva-brunello-di-montalcino',
#    'appellation': 'Brunello Di Montalcino',
#    'appellation_slug': 'brunello-di-montalcino',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Tuscany'],
#    'country': 'Italy',
#    'classification': None,
#    'vintage': '2012',
#    'date': '2020-07-29',
#    'is_primeurs': False,
#    'score': 95.95,
#    'confidence_index': 'B',
#    'journalist_count': 5,
#    'lwin': 1174687,
#    'lwin_11': 11746872012},
#   {'wine': 'Marchesi Antinori, Pian delle Vigne, Brunello Di Montalcino',
#    'wine_id': 148605,
#    'wine_slug': 'marchesi-antinori-pian-delle-vigne-brunello-di-montalcino',
#    'appellation': 'Brunello Di Montalcino',
#    'appellation_slug': 'brunello-di-montalcino',
#    'color': 'Red',
#    'wine_type': '',
# ...

# %%
#Create a dataframe
wine_Italy_df = pd.DataFrame.from_dict(obj_Italy['results'], orient='columns')
wine_Italy_df
# Out:
#                                                    wine  wine_id  \
# 0     Biondi Santi Tenuta Greppo, Riserva, Brunello ...    12050
# 1     Marchesi Antinori, Pian delle Vigne, Brunello ...   148605
# 2     Brovia, Rocche-Villero 150 Anniversario, Barol...    21943
# 3                       Gaja, Sori Tildin, Langhe Rosso   147411
# 4                  Gaja, Costa Russi, Langhe Barbaresco   147629
# ...                                                 ...      ...
# 1626                            Vietti, Brunate, Barolo   148560
# 1627                            Brovia, Villero, Barolo    21948
# 1628                          Vietti, Lazzarito, Barolo   148540
# 1629               Gaja, Costa Russi, Langhe Barbaresco   147629
# 1630                       Gaja, Barbaresco, Barbaresco   147628
#
#                                               wine_slug  \
# 0     biondi-santi-tenuta-greppo-riserva-brunello-di...
# 1     marchesi-antinori-pian-delle-vigne-brunello-di...
# ...
