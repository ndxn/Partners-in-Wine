# %%
# Import the requests library.
import requests
import numpy as np
import pandas as pd
# Import the requests library.
import requests
import datetime
from datetime import datetime
import matplotlib.pyplot as plt
# Dependencies for the wine API
import urllib
import json
# Import the API key.
from config import weather_api_key

# %% [markdown]
# ## Dropped Columns
# Wine and wine_slug appear to be the same columns <p>
# appellation and appellation_slug appear to be the same columns <p>
# wine_type is blank <p>
# classification has several NA values <p>
# lwin and lwin_11 are unique identifiers for that particular wine <p>

# %%
# Import the API key.
API_Token='Token d8f94b93417333267ca0edcca7dc14a9e035e1bb'
headers = {
    'accept': 'application/json',
    'authorization': API_Token
    }

# %% [markdown]
# # Red Wine in USA

# %%
req_red_USA = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=red&limit=5000&country=Usa', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)
res_red_USA = urllib.request.urlopen(req_red_USA).read().decode()
obj_red_USA = json.loads(res_red_USA)
#read json into DF
Red_USA_df = pd.DataFrame.from_dict(obj_red_USA['results'], orient='columns')
# To delete the column without having to reassign df you can do:
Red_USA_df.drop([ 'wine_slug', 'appellation_slug',  'date',  'lwin', 'lwin_11'],axis=1, inplace=True)
#'wine_id','wine_type','classification',
#Drop NA values
# Red_USA_df = Red_USA_df.dropna()
#convert vintage to date type
Red_USA_df['vintage']= pd.to_datetime(Red_USA_df['vintage'])
Red_USA_df.head(50)
# Out:
#                                                  wine  wine_id  \
# 0                               Quintessa, Rutherford   118360
# 1                          Harlan Estate, Napa Valley    81980
# 2            Dalla Valle Vineyards, Maya, Napa Valley    48290
# 3   Philip Togni Vineyard, Cabernet Sauvignon, Nap...   115154
# 4             Colgin Cellars, Cariad Red, Napa Valley    44618
# 5                  Sloan, Proprietary Red, Rutherford   128313
# 6   Shafer Vineyards, Hillside Select Cabernet Sau...   126746
# 7   Dalla Valle Vineyards, Cabernet Sauvignon, Nap...    48287
# 8       Dominus Estate, Christian Moueix, Napa Valley    67008
# 9   Beringer Vineyards, Private Reserve Cabernet S...    11029
# 10                     Verite, La Joie, Sonoma County   139098
# 11           Corison, Cabernet Sauvignon, Napa Valley    46229
# 12                              Opus One, Napa Valley   111085
# 13                     Viader, Red Blend, Napa Valley   139371
# 14  Ridge Vineyards, Monte Bello, Santa Cruz Mount...   120786
# 15  Schrader Cellars, Beckstoffer To Kalon Vineyar...   125492
# 16                         Harlan Estate, Napa Valley    81980
# 17           Dalla Valle Vineyards, Maya, Napa Valley    48290
# 18  Bryant Family Vineyard, Cabernet Sauvignon, Na...    22244
# 19      Dominus Estate, Christian Moueix, Napa Valley    67008
# 20  Spottswoode, Family Estate Grown Cabernet Sauv...   129353
# 21  Shafer Vineyards, Hillside Select Cabernet Sau...   126746
# 22                     Verite, La Muse, Sonoma County   139099
# 23                              Opus One, Napa Valley   111085
# 24  Morlet Family Vineyards, Coeur De Vallee Caber...   107391
# 25   Forman Vineyard, Cabernet Sauvignon, Napa Valley    75322
# 26  Philip Togni Vineyard, Cabernet Sauvignon, Nap...   115154
# 27                            Promontory, Napa Valley   117679
# 28  Ramey Wine Cellars, Pedregal Vineyard Cabernet...   118768
# 29     Joseph Phelps Vineyards, Insignia, Napa Valley    89577
# 30                    Verite, Le Desir, Sonoma County   139100
# 31  Ramey Wine Cellars, Annum Cabernet Sauvignon, ...   118755
# 32  Dalla Valle Vineyards, Cabernet Sauvignon, Nap...    48287
# 33  Ridge Vineyards, Monte Bello, Santa Cruz Mount...   120786
# 34  Diamond Creek, Red Rock Terrace Cabernet Sauvi...    50664
# 35  Anakota, Helena Dakota Vineyard Cabernet Sauvi...     4040
# 36                                  Futo Ov, Oakville    77304
# 37                     Verite, La Joie, Sonoma County   139098
# 38  Chappellet, Pritchard Hill Cabernet Sauvignon,...    31619
# 39                     Viader, Red Blend, Napa Valley   139371
# 40  Cliff Lede Vineyards, Poetry Cabernet Sauvigno...    43385
# 41  Beringer Vineyards, Private Reserve Cabernet S...    11029
# 42  Chateau Montelena The Montelena Estate, Cabern...    39438
# 43                              Quintessa, Rutherford   118360
# 44            Pahlmeyer, Proprietary Red, Napa Valley   111900
# 45           Corison, Cabernet Sauvignon, Napa Valley    46229
# 46  Robert Craig Winery, Howell Mountain Cabernet ...   121297
# 47  Turnbull Wine Cellars, Leopoldina Vineyard Cab...   137302
# 48  Stag'S Leap Wine Cellars, Estate Cask 23 Caber...   129784
# 49  Cliff Lede Vineyards, Cabernet Sauvignon, Stag...    43378
#
#              appellation color wine_type       regions country classification  \
# 0             Rutherford   Red            [California]     Usa           None
# 1            Napa Valley   Red            [California]     Usa           None
# 2            Napa Valley   Red            [California]     Usa           None
# 3            Napa Valley   Red            [California]     Usa           None
# 4            Napa Valley   Red            [California]     Usa           None
# 5             Rutherford   Red            [California]     Usa           None
# 6    Stags Leap District   Red            [California]     Usa           None
# 7            Napa Valley   Red            [California]     Usa           None
# 8            Napa Valley   Red            [California]     Usa           None
# 9            Napa Valley   Red            [California]     Usa           None
# 10         Sonoma County   Red            [California]     Usa           None
# 11           Napa Valley   Red            [California]     Usa           None
# 12           Napa Valley   Red            [California]     Usa           None
# 13           Napa Valley   Red            [California]     Usa           None
# 14  Santa Cruz Mountains   Red            [California]     Usa           None
# 15           Napa Valley   Red            [California]     Usa           None
# 16           Napa Valley   Red            [California]     Usa           None
# 17           Napa Valley   Red            [California]     Usa           None
# 18           Napa Valley   Red            [California]     Usa           None
# 19           Napa Valley   Red            [California]     Usa           None
# 20             St Helena   Red            [California]     Usa           None
# 21   Stags Leap District   Red            [California]     Usa           None
# 22         Sonoma County   Red            [California]     Usa           None
# 23           Napa Valley   Red            [California]     Usa           None
# 24              Oakville   Red            [California]     Usa           None
# 25           Napa Valley   Red            [California]     Usa           None
# 26           Napa Valley   Red            [California]     Usa           None
# 27           Napa Valley   Red            [California]     Usa           None
# 28              Oakville   Red            [California]     Usa           None
# 29           Napa Valley   Red            [California]     Usa           None
# 30         Sonoma County   Red            [California]     Usa           None
# 31           Napa Valley   Red            [California]     Usa           None
# 32           Napa Valley   Red            [California]     Usa           None
# 33  Santa Cruz Mountains   Red            [California]     Usa           None
# 34           Napa Valley   Red            [California]     Usa           None
# 35        Knights Valley   Red            [California]     Usa           None
# 36              Oakville   Red            [California]     Usa           None
# 37         Sonoma County   Red            [California]     Usa           None
# 38           Napa Valley   Red            [California]     Usa           None
# 39           Napa Valley   Red            [California]     Usa           None
# 40   Stags Leap District   Red            [California]     Usa           None
# 41           Napa Valley   Red            [California]     Usa           None
# 42           Napa Valley   Red            [California]     Usa           None
# 43            Rutherford   Red            [California]     Usa           None
# 44           Napa Valley   Red            [California]     Usa           None
# 45           Napa Valley   Red            [California]     Usa           None
# 46           Napa Valley   Red            [California]     Usa           None
# 47              Oakville   Red            [California]     Usa           None
# 48           Napa Valley   Red            [California]     Usa           None
# 49   Stags Leap District   Red            [California]     Usa           None
#
#       vintage  is_primeurs  score confidence_index  journalist_count
# 0  2015-01-01        False  95.77                C                 3
# 1  2001-01-01        False  98.89               A+                 6
# 2  2001-01-01        False  96.49               B+                 5
# 3  2001-01-01        False  96.20                B                 3
# 4  2001-01-01        False  95.60                B                 5
# 5  2001-01-01        False  95.19               C+                 3
# 6  2001-01-01        False  93.69                C                 6
# 7  2001-01-01        False  93.66               B+                 5
# 8  2001-01-01        False  93.60                B                10
# 9  2001-01-01        False  93.25               C+                 3
# 10 2001-01-01        False  92.37                C                 3
# 11 2001-01-01        False  92.20               C+                 6
# 12 2001-01-01        False  91.88                B                 8
# 13 2001-01-01        False  90.58                B                 3
# 14 1991-01-01        False  95.90                B                 8
# 15 2009-01-01        False  95.09               C+                 5
# 16 2010-01-01        False  98.41                B                 8
# 17 2010-01-01        False  97.63                B                 5
# 18 2010-01-01        False  97.00                A                 5
# 19 2010-01-01        False  96.30               C+                 9
# 20 2010-01-01        False  96.20                B                 8
# 21 2010-01-01        False  96.16               C+                 8
# 22 2010-01-01        False  96.11               C+                 3
# 23 2010-01-01        False  95.99                B                 8
# 24 2010-01-01        False  95.92               C+                 3
# 25 2010-01-01        False  95.75               C+                 3
# 26 2010-01-01        False  95.57                C                 3
# 27 2010-01-01        False  95.47                B                 5
# 28 2010-01-01        False  95.35                B                 4
# 29 2010-01-01        False  95.31               B+                 8
# 30 2010-01-01        False  95.12               C+                 3
# 31 2010-01-01        False  94.88               B+                 3
# 32 2010-01-01        False  94.62                B                 6
# 33 2010-01-01        False  94.41                B                 9
# 34 2010-01-01        False  94.19                A                 7
# 35 2010-01-01        False  94.08                B                 3
# 36 2010-01-01        False  94.04               B+                 3
# 37 2010-01-01        False  93.37                B                 3
# 38 2010-01-01        False  93.33                B                 5
# 39 2010-01-01        False  93.29               C+                 4
# 40 2010-01-01        False  93.29                B                 6
# 41 2010-01-01        False  92.78                B                 9
# 42 2010-01-01        False  92.70               B+                 8
# 43 2010-01-01        False  92.67               B+                 6
# 44 2010-01-01        False  92.66               B+                 3
# 45 2010-01-01        False  92.50                B                 7
# 46 2010-01-01        False  92.05               B+                 5
# 47 2010-01-01        False  91.75                B                 5
# 48 2010-01-01        False  91.62               C+                 4
# 49 2010-01-01        False  90.48                A                 6

# %% [markdown]
# # White Wine in USA

# %%
req_white_USA = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=white&limit=5000&country=Usa', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)
res_white_USA = urllib.request.urlopen(req_white_USA).read().decode()
obj_white_USA = json.loads(res_white_USA)
#read json into DF
white_USA_df = pd.DataFrame.from_dict(obj_white_USA['results'], orient='columns')
# To delete the column without having to reassign df you can do:
white_USA_df.drop([ 'wine_slug', 'appellation_slug',  'date',  'lwin', 'lwin_11'],axis=1, inplace=True)
#'wine_id','wine_type','classification',
#Drop NA values
# white_USA_df = white_USA_df.dropna()
#convert vintage to date type
white_USA_df['vintage']= pd.to_datetime(white_USA_df['vintage'])
white_USA_df.head()
# Out:
#                                                 wine  wine_id  \
# 0  Ridge Vineyards, Monte Bello Chardonnay, White...   120785
# 1  Stags' Leap Winery, Chardonnay, White, Napa Va...   129823
# 2  Joseph Phelps Vineyards, Freestone Chardonnay,...    89569
# 3  Crossbarn By Paul Hobbs, Chardonnay, White, So...    47377
# 4  Mount Eden Vineyards, Chardonnay, White, Santa...   107658
#
#             appellation  color wine_type       regions country classification  \
# 0  Santa Cruz Mountains  White       dry  [California]     Usa           None
# 1           Napa Valley  White       dry  [California]     Usa           None
# 2          Sonoma Coast  White       dry  [California]     Usa           None
# 3          Sonoma Coast  White       dry  [California]     Usa           None
# 4  Santa Cruz Mountains  White       dry  [California]     Usa           None
#
#      vintage  is_primeurs  score confidence_index  journalist_count
# 0 2016-01-01        False  94.39                B                 3
# 1 2016-01-01        False  89.83               A+                 3
# 2 2016-01-01        False  90.73               C+                 4
# 3 2016-01-01        False  90.39               B+                 3
# 4 2015-01-01        False  92.22                B                 4

# %% [markdown]
# # Red Wine in France

# %%
# req = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=red&limit=5000&country=France', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)
# res = urllib.request.urlopen(req).read().decode()
# obj = json.loads(res)
# #read json file into DF
# df = pd.DataFrame.from_dict(obj['results'], orient='columns')
# # To delete the column without having to reassign df you can do:
# df.drop([ 'wine_slug', 'appellation_slug', 'date',  'lwin', 'lwin_11'],axis=1, inplace=True)
# # 'wine_type','wine_id','classification',
# for i in df:
#     print(f"{i} has {df[i].isnull().sum()} null values")
# #Drop NA values
# df = df.dropna()
# for i in df:
#     print(f"{i} has {df[i].isnull().sum()} null values")
# # convert vintage to date time
# df['vintage']= pd.to_datetime(df['vintage'])
# df.dtypes

# %% [markdown]
# # White Wine in France

# %%
# req_white = urllib.request.Request('https://api.globalwinescore.com/globalwinescores/latest/?color=white&limit=5000&country=France', data=None, headers=headers, origin_req_host=None, unverifiable=False, method=None)
# res_white = urllib.request.urlopen(req_white).read().decode()
# obj_white = json.loads(res_white)
# #read into DF
# White_France_df = pd.DataFrame.from_dict(obj_white['results'], orient='columns')
# # To delete the column without having to reassign df you can do:
# White_France_df.drop([ 'wine_slug', 'appellation_slug', 'date', 'lwin', 'lwin_11'],axis=1, inplace=True)
# # 'wine_type','wine_id', 'classification',
# #drop null values
# White_France_df = White_France_df.dropna()
# #  convert to date time 
# White_France_df['vintage']= pd.to_datetime(White_France_df['vintage'])

# %% [markdown]
# # Weather

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Des Moines"
print(city_url)
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url).json()
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
# convert date to year-month-day, hour-minute-second
city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#identify which columns we want to view by creating an empty list and appending that list
city_data=[]
city_data.append({
    "Lat": city_lat,
    "Lng": city_lng,
    "Max Temp": city_max_temp,
    "Humidity": city_humidity,
    "Cloudiness": city_clouds,
    "Wind Speed": city_wind,
    "Country": city_country,
    "Date": city_date})
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cb263315761782d33f16c9fb510ae6c3
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cb263315761782d33f16c9fb510ae6c3&q=Des Moines
#     Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 0  41.6 -93.61        75        28          75       21.92      US
#
#                   Date
# 0  2020-10-14 21:13:53

# %%
# Request Endpoint:      /access/services/data/v1
# Datasets:              ?dataset=daily-summaries
#Station Ids:            &stations=USC00457180,USC00390043
#Start Date:             &startDate=1941-12-07T09:31:20z
        #date (YYYY-MM-DD) -or- ISO 8601 combined date and time format (YYYY-MM-DDTHH:mm:ss).
        # If using ISO 8601 the T that separates the time is NOT optional
        #ISO 8601 date format example: 2001-11-02T12:45:00Z
#End Date:               &endDate=1945-07-12
#Date Format:            &format=json
#Results Option:         &includeAttributes=0&includeStationName=true

# %%
#Info for the NOAA weather API
# https://towardsdatascience.com/getting-weather-data-in-3-easy-steps-8dc10cc5c859

# %%
#find the weather station
# https://www.ncdc.noaa.gov/cdo-web/datatools/findstation

#add the access token you got from NOAA
Token = 'tylRGHbxqiZUDNymMowCBFCuEqeULiWk'
#Nappa Valley
station_id = 'GHCND:USC00046074'
#initialize lists to store data
dates_temp = []
dates_prcp = []
temps = []
prcp = []

#for each year from 2015-2019 ...
for year in range(2015, 2020):
    year = str(year)
    print('working on year '+year)
    
    #make the api call
    r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
    #load the api response as a json
    d = json.loads(r.text)
    #get all items in the response which are average temperature readings
    avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']
    #get the date field from all average temperature readings
    dates_temp += [item['date'] for item in avg_temps]
    #get the actual average temperature from all average temperature readings
    temps += [item['value'] for item in avg_temps]

#initialize dataframe
df_temp = pd.DataFrame()

#populate date and average temperature fields (cast string date to datetime
df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
#convert to degrees F
df_temp['avgTemp'] = [float(v)/10.0*1.8 + 32 for v in temps]
df_temp
# Out:
# working on year 2015
# working on year 2016
# working on year 2017
# working on year 2018
# working on year 2019
#            date  avgTemp
# 0    2015-01-01    46.58
# 1    2015-01-02    48.02
# 2    2015-01-03    49.82
# 3    2015-01-04    52.16
# 4    2015-01-05    58.64
# ...         ...      ...
# 1821 2019-12-27    49.10
# 1822 2019-12-28    50.90
# 1823 2019-12-29    51.26
# 1824 2019-12-30    54.68
# 1825 2019-12-31    58.46
#
# [1826 rows x 2 columns]

# %%
d
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2019-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 128},
#   {'date': '2019-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 105},
#   {'date': '2019-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2019-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2019-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 123},
#   {'date': '2019-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 124},
#   {'date': '2019-01-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 132},
#   {'date': '2019-01-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 146},
#   {'date': '2019-01-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 143},
#   {'date': '2019-01-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 137},
#   {'date': '2019-01-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 139},
#   {'date': '2019-01-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 133},
#   {'date': '2019-01-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 120},
#   {'date': '2019-01-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 128},
#   {'date': '2019-01-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 127},
#   {'date': '2019-01-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 136},
#   {'date': '2019-01-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-01-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 151},
#   {'date': '2019-01-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 160},
#   {'date': '2019-01-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 172},
#   {'date': '2019-01-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 156},
#   {'date': '2019-01-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 133},
#   {'date': '2019-01-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 133},
#   {'date': '2019-01-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 146},
#   {'date': '2019-01-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 167},
#   {'date': '2019-01-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 171},
#   {'date': '2019-01-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-01-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 154},
#   {'date': '2019-01-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 162},
#   {'date': '2019-01-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 152},
#   {'date': '2019-01-31T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 144},
#   {'date': '2019-02-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 131},
#   {'date': '2019-02-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 144},
#   {'date': '2019-02-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 125},
#   {'date': '2019-02-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 134},
#   {'date': '2019-02-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 123},
#   {'date': '2019-02-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 102},
#   {'date': '2019-02-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 103},
#   {'date': '2019-02-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 110},
#   {'date': '2019-02-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2019-02-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 113},
#   {'date': '2019-02-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 97},
#   {'date': '2019-02-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 112},
#   {'date': '2019-02-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 132},
#   {'date': '2019-02-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 141},
#   {'date': '2019-02-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 132},
#   {'date': '2019-02-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 127},
#   {'date': '2019-02-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 118},
#   {'date': '2019-02-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 104},
#   {'date': '2019-02-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 96},
#   {'date': '2019-02-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 98},
#   {'date': '2019-02-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 108},
#   {'date': '2019-02-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 87},
#   {'date': '2019-02-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 110},
#   {'date': '2019-02-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 124},
#   {'date': '2019-02-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 130},
#   {'date': '2019-02-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 128},
#   {'date': '2019-02-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 142},
#   {'date': '2019-02-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 158},
#   {'date': '2019-03-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 157},
#   {'date': '2019-03-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 149},
#   {'date': '2019-03-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 154},
#   {'date': '2019-03-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 145},
#   {'date': '2019-03-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 134},
#   {'date': '2019-03-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 148},
#   {'date': '2019-03-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 146},
#   {'date': '2019-03-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 132},
#   {'date': '2019-03-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 124},
#   {'date': '2019-03-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 123},
#   {'date': '2019-03-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 132},
#   {'date': '2019-03-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 157},
#   {'date': '2019-03-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 141},
#   {'date': '2019-03-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 149},
#   {'date': '2019-03-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 166},
#   {'date': '2019-03-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 184},
#   {'date': '2019-03-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 202},
#   {'date': '2019-03-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 184},
#   {'date': '2019-03-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 146},
#   {'date': '2019-03-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 161},
#   {'date': '2019-03-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 141},
#   {'date': '2019-03-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 137},
#   {'date': '2019-03-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 152},
#   {'date': '2019-03-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 161},
#   {'date': '2019-03-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-03-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 158},
#   {'date': '2019-03-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-03-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 170},
#   {'date': '2019-03-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 160},
#   {'date': '2019-03-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 177},
#   {'date': '2019-03-31T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 196},
#   {'date': '2019-04-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 211},
#   {'date': '2019-04-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 185},
#   {'date': '2019-04-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 167},
#   {'date': '2019-04-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 161},
#   {'date': '2019-04-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-04-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 171},
#   {'date': '2019-04-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 179},
#   {'date': '2019-04-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 211},
#   {'date': '2019-04-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 203},
#   {'date': '2019-04-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-04-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 174},
#   {'date': '2019-04-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 169},
#   {'date': '2019-04-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 179},
#   {'date': '2019-04-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 180},
#   {'date': '2019-04-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 153},
#   {'date': '2019-04-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 156},
#   {'date': '2019-04-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 166},
#   {'date': '2019-04-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 191},
#   {'date': '2019-04-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 180},
#   {'date': '2019-04-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 159},
#   {'date': '2019-04-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 162},
#   {'date': '2019-04-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 166},
#   {'date': '2019-04-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 174},
#   {'date': '2019-04-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 179},
#   {'date': '2019-04-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 174},
#   {'date': '2019-04-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 172},
#   {'date': '2019-04-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 166},
#   {'date': '2019-04-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 168},
#   {'date': '2019-04-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 166},
#   {'date': '2019-04-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 167},
#   {'date': '2019-05-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 166},
#   {'date': '2019-05-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2019-05-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2019-05-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 177},
#   {'date': '2019-05-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 174},
#   {'date': '2019-05-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2019-05-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2019-05-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 171},
#   {'date': '2019-05-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2019-05-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 171},
#   {'date': '2019-05-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 183},
#   {'date': '2019-05-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 186},
#   {'date': '2019-05-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 180},
#   {'date': '2019-05-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 186},
#   {'date': '2019-05-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 179},
#   {'date': '2019-05-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 176},
#   {'date': '2019-05-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 169},
#   {'date': '2019-05-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 169},
#   {'date': '2019-05-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 153},
#   {'date': '2019-05-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 169},
#   {'date': '2019-05-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 170},
#   {'date': '2019-05-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 167},
#   {'date': '2019-05-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 161},
#   {'date': '2019-05-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 170},
#   {'date': '2019-05-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 172},
#   {'date': '2019-05-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 161},
#   {'date': '2019-05-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 150},
#   {'date': '2019-05-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-05-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 182},
#   {'date': '2019-05-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 183},
#   {'date': '2019-05-31T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 172},
#   {'date': '2019-06-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 169},
#   {'date': '2019-06-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 171},
#   {'date': '2019-06-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 179},
#   {'date': '2019-06-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 174},
#   {'date': '2019-06-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 176},
#   {'date': '2019-06-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 182},
#   {'date': '2019-06-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 179},
#   {'date': '2019-06-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 183},
#   {'date': '2019-06-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 194},
#   {'date': '2019-06-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 225},
#   {'date': '2019-06-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 223},
#   {'date': '2019-06-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 218},
#   {'date': '2019-06-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 191},
#   {'date': '2019-06-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 183},
#   {'date': '2019-06-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 189},
#   {'date': '2019-06-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 194},
#   {'date': '2019-06-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 188},
#   {'date': '2019-06-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 183},
#   {'date': '2019-06-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-06-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 196},
#   {'date': '2019-06-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 190},
#   {'date': '2019-06-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 198},
#   {'date': '2019-06-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-06-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 190},
#   {'date': '2019-06-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 188},
#   {'date': '2019-06-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 194},
#   {'date': '2019-06-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 202},
#   {'date': '2019-06-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 206},
#   {'date': '2019-06-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 213},
#   {'date': '2019-06-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 231},
#   {'date': '2019-07-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 222},
#   {'date': '2019-07-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 216},
#   {'date': '2019-07-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 213},
#   {'date': '2019-07-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 209},
#   {'date': '2019-07-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 204},
#   {'date': '2019-07-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 204},
#   {'date': '2019-07-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 192},
#   {'date': '2019-07-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 198},
#   {'date': '2019-07-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 213},
#   {'date': '2019-07-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 209},
#   {'date': '2019-07-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 213},
#   {'date': '2019-07-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 218},
#   {'date': '2019-07-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 212},
#   {'date': '2019-07-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 214},
#   {'date': '2019-07-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 217},
#   {'date': '2019-07-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 221},
#   {'date': '2019-07-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 213},
#   {'date': '2019-07-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 217},
#   {'date': '2019-07-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 213},
#   {'date': '2019-07-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 222},
#   {'date': '2019-07-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 222},
#   {'date': '2019-07-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 221},
#   {'date': '2019-07-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 261},
#   {'date': '2019-07-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 279},
#   {'date': '2019-07-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 266},
#   {'date': '2019-07-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 265},
#   {'date': '2019-07-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 261},
#   {'date': '2019-07-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 241},
#   {'date': '2019-07-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 224},
#   {'date': '2019-07-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 228},
#   {'date': '2019-07-31T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 227},
#   {'date': '2019-08-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 232},
#   {'date': '2019-08-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 232},
#   {'date': '2019-08-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 240},
#   {'date': '2019-08-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 238},
#   {'date': '2019-08-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 234},
#   {'date': '2019-08-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 240},
#   {'date': '2019-08-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 224},
#   {'date': '2019-08-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 218},
#   {'date': '2019-08-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 217},
#   {'date': '2019-08-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 220},
#   {'date': '2019-08-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 223},
#   {'date': '2019-08-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 213},
#   {'date': '2019-08-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 226},
#   {'date': '2019-08-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 222},
#   {'date': '2019-08-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 222},
#   {'date': '2019-08-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 209},
#   {'date': '2019-08-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 212},
#   {'date': '2019-08-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 219},
#   {'date': '2019-08-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 223},
#   {'date': '2019-08-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 226},
#   {'date': '2019-08-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 237},
#   {'date': '2019-08-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 233},
#   {'date': '2019-08-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 218},
#   {'date': '2019-08-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 239},
#   {'date': '2019-08-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 251},
#   {'date': '2019-08-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 260},
#   {'date': '2019-08-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 245},
#   {'date': '2019-08-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 236},
#   {'date': '2019-08-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 244},
#   {'date': '2019-08-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 256},
#   {'date': '2019-08-31T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 249},
#   {'date': '2019-09-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 235},
#   {'date': '2019-09-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 246},
#   {'date': '2019-09-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 271},
#   {'date': '2019-09-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 279},
#   {'date': '2019-09-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 274},
#   {'date': '2019-09-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 272},
#   {'date': '2019-09-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 259},
#   {'date': '2019-09-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 229},
#   {'date': '2019-09-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 228},
#   {'date': '2019-09-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 223},
#   {'date': '2019-09-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 223},
#   {'date': '2019-09-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 236},
#   {'date': '2019-09-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 253},
#   {'date': '2019-09-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 256},
#   {'date': '2019-09-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 247},
#   {'date': '2019-09-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 229},
#   {'date': '2019-09-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 228},
#   {'date': '2019-09-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 223},
#   {'date': '2019-09-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 222},
#   {'date': '2019-09-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 222},
#   {'date': '2019-09-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 229},
#   {'date': '2019-09-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 244},
#   {'date': '2019-09-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 229},
#   {'date': '2019-09-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 227},
#   {'date': '2019-09-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 234},
#   {'date': '2019-09-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 226},
#   {'date': '2019-09-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 226},
#   {'date': '2019-09-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 214},
#   {'date': '2019-09-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-09-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 190},
#   {'date': '2019-10-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 190},
#   {'date': '2019-10-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-10-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-10-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 193},
#   {'date': '2019-10-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 207},
#   {'date': '2019-10-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 216},
#   {'date': '2019-10-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 221},
#   {'date': '2019-10-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 205},
#   {'date': '2019-10-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 198},
#   {'date': '2019-10-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 207},
#   {'date': '2019-10-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 233},
#   {'date': '2019-10-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 224},
#   {'date': '2019-10-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 194},
#   {'date': '2019-10-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 192},
#   {'date': '2019-10-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-10-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 216},
#   {'date': '2019-10-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 206},
#   {'date': '2019-10-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 203},
#   {'date': '2019-10-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 197},
#   {'date': '2019-10-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 209},
#   {'date': '2019-10-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 249},
#   {'date': '2019-10-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 254},
#   {'date': '2019-10-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 238},
#   {'date': '2019-10-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 248},
#   {'date': '2019-10-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 284},
#   {'date': '2019-10-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 233},
#   {'date': '2019-10-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-10-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 187},
#   {'date': '2019-10-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 174},
#   {'date': '2019-10-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 179},
#   {'date': '2019-10-31T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 182},
#   {'date': '2019-11-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 189},
#   {'date': '2019-11-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 181},
#   {'date': '2019-11-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 174},
#   {'date': '2019-11-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 182},
#   {'date': '2019-11-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 175},
#   {'date': '2019-11-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-11-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2019-11-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 187},
#   {'date': '2019-11-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 209},
#   {'date': '2019-11-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 181},
#   {'date': '2019-11-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 173},
#   {'date': '2019-11-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 171},
#   {'date': '2019-11-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-11-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 160},
#   {'date': '2019-11-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 161},
#   {'date': '2019-11-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 161},
#   {'date': '2019-11-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 197},
#   {'date': '2019-11-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 223},
#   {'date': '2019-11-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 201},
#   {'date': '2019-11-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 157},
#   {'date': '2019-11-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 134},
#   {'date': '2019-11-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 148},
#   {'date': '2019-11-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 168},
#   {'date': '2019-11-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 169},
#   {'date': '2019-11-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 143},
#   {'date': '2019-11-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 146},
#   {'date': '2019-11-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 136},
#   {'date': '2019-11-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 103},
#   {'date': '2019-11-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 86},
#   {'date': '2019-11-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 102},
#   {'date': '2019-12-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 127},
#   {'date': '2019-12-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 137},
#   {'date': '2019-12-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 140},
#   {'date': '2019-12-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 148},
#   {'date': '2019-12-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 139},
#   {'date': '2019-12-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 148},
#   {'date': '2019-12-07T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 162},
#   {'date': '2019-12-08T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 164},
#   {'date': '2019-12-09T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 141},
#   {'date': '2019-12-10T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 138},
#   {'date': '2019-12-11T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 133},
#   {'date': '2019-12-12T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 144},
#   {'date': '2019-12-13T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 141},
#   {'date': '2019-12-14T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 153},
#   {'date': '2019-12-15T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 139},
#   {'date': '2019-12-16T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 126},
#   {'date': '2019-12-17T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 148},
#   {'date': '2019-12-18T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 118},
#   {'date': '2019-12-19T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 111},
#   {'date': '2019-12-20T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 137},
#   {'date': '2019-12-21T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 149},
#   {'date': '2019-12-22T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 138},
#   {'date': '2019-12-23T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 127},
#   {'date': '2019-12-24T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 108},
#   {'date': '2019-12-25T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 118},
#   {'date': '2019-12-26T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 104},
#   {'date': '2019-12-27T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 95},
#   {'date': '2019-12-28T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 105},
#   {'date': '2019-12-29T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 107},
#   {'date': '2019-12-30T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 126},
#   {'date': '2019-12-31T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00023129',
#    'attributes': 'H,,S,',
#    'value': 147}]}

# %%
# #find the weather station
# # https://www.ncdc.noaa.gov/cdo-web/datatools/findstation

# #add the access token you got from NOAA
# Token = 'tylRGHbxqiZUDNymMowCBFCuEqeULiWk'
# #Nappa Valley
# station_id = 'GHCND:USC00046074'
# #initialize lists to store data
# dates_temp = []
# dates_prcp = []
# temps = []
# prcp = []

# #for each year from 2015-2019 ...
# for year in range(2015, 2020):
#     year = str(year)
#     print('working on year '+year)
    
#     #make the api call
#     r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=PRCP&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
#     #load the api response as a json
#     e = json.loads(r.text)
#     #get all items in the response which are average precipitation readings
#     avg_p = [item for item in e['results'] if item['datatype']=='PRCP']
#     #get the date field from all average precipitation readings
#     dates_prcp += [item['date'] for item in avg_p]
#     #get the actual average precipitation from all average precipitation readings
#     temps += [item['value'] for item in avg_p]

# #initialize dataframe
# df_prep = pd.DataFrame()

# #populate date and average temperature fields (cast string date to datetime
# df_prep['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for e in dates_prcp]
# #convert to degrees F
# # df_temp['avgTemp'] = [float(v)/10.0*1.8 + 32 for v in temps]
# df_prep

# %%
# e
