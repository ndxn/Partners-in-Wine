# %%
# Import the requests library.
import requests
import numpy as np
import pandas as pd
# Import the requests library.
import requests
import datetime
from datetime import datetime
import matplotlib.pyplot as plt
# Dependencies for the wine API
import urllib
import json
# Import the API key.
#from config import weather_api_key
#from config import Token
#from config import API_Token
#import calendar

# %%
# Import the API key.
headers = {
    'accept': 'application/json',
    'authorization': API_Token
    }

# %%
# Read appellation geo
appellations_geo_df: pd.DataFrame = pd.read_csv('./Database data/appellations_geo.csv')
appellations_geo_df
# Out:
#                   appellation  count  app_lat   app_lon
# 0            Alexander Valley     32  38.6130 -122.7694
# 1               Amador County      4  38.3489 -120.7741
# 2             Anderson Valley      2  40.4482 -122.2978
# 3                  Atlas Peak      6  38.3195 -122.2559
# 4              Bennett Valley      2  38.4405 -122.6767
# 5                  California     45      NaN       NaN
# 6                   Calistoga      4  38.5788 -122.5797
# 7                    Carneros    199  38.2554 -122.3325
# 8                  Chalk Hill      6  38.6038 -122.7772
# 9          Chehalem Mountains      1  45.3762 -123.0373
# 10            Columbia Valley    230  47.1211 -119.2883
# 11                Coombsville      9  38.3050 -122.2444
# 12  Diamond Mountain District     17  38.5506 -122.5396
# 13           Dry Creek Valley     29  38.6999 -122.9666
# 14               Dundee Hills     45  45.2762 -123.0125
# 15           Eola-Amity Hills     38  45.0560 -123.1160
# 16               Green Valley     13  38.4200 -122.9000
# 17         Horse Heaven Hills     41  46.1332 -119.8678
# 18            Howell Mountain    165  38.5765 -122.4584
# 19             Knights Valley     94  38.6333 -122.6833
# 20               Los Carneros      8  38.2647 -122.3422
# 21           Mendocino County      1  39.5500 -123.4384
# 22            Mendocino Ridge      2  39.1345 -123.6456
# 23                   Monterey      1  36.4334 -121.3270
# 24                 Monticello      1      NaN       NaN
# 25               Mount Harlan      1  36.7363 -121.3695
# 26               Mount Veeder     23  38.3794 -122.4478
# 27                Napa County     17  38.5025 -122.2654
# 28                Napa Valley   2388  38.5025 -122.2654
# 29                North Coast      1      NaN       NaN
# 30         Oak Knoll District     11  38.3583 -122.3339
# 31                   Oakville    208  38.4367 -122.4028
# 32                     Oregon      7      NaN       NaN
# 33                Paso Robles     13  35.6369 -120.6545
# 34               Red Mountain     60  46.2979 -119.4409
# 35               Ribbon Ridge      3  45.3594 -123.0944
# 36       Russian River Valley    216  38.4836 -122.8175
# 37                 Rutherford    135  38.4591 -122.4226
# 38     San Luis Obispo County      1  35.2828 -120.6596
# 39       Santa Cruz Mountains     72  37.1109 -121.8449
# 40      Santa Lucia Highlands     16  36.4469 -121.4848
# 41         Santa Maria Valley      1  34.8123 -120.3481
# 42          Santa Ynez Valley      7  34.5842 -120.0974
# 43           Sierra Foothills      2  38.0902 -120.4736
# 44            Snipes Mountain      1  46.3285 -120.0080
# 45               Sonoma Coast    128  38.3641 -122.9755
# 46              Sonoma County    149  38.5780 -122.9888
# 47            Sonoma Mountain     29  38.3230 -122.5750
# 48              Sonoma Valley      4  38.3669 -122.4975
# 49   Spring Mountain District     31  38.5325 -122.5494
# 50                  St Helena     94  38.5052 -122.4704
# 51             Sta Rita Hills      2  34.6660 -120.1152
# 52        Stags Leap District    122  38.4141 -122.3213
# 53         Walla Walla Valley    271  46.0000  118.5000
# 54                 Washington      6      NaN       NaN
# 55          Willamette Valley     41  44.9426 -122.9338
# 56              Yakima Valley     69  46.3289 -120.0086
# 57                 Yountville     24  38.4016 -122.3608

# %%
# Initialize DF
#soils_df: pd.DataFrame = pd.DataFrame(columns = ['appellation', 'coordinates']) 
#soils_df
# Out:
# Empty DataFrame
# Columns: [appellation, coordinates]
# Index: []

# %% [markdown]
# # SoilGrids API

# %%
#for appellation in appellations_geo_df:
#    print(appellations_geo_df['appellation'])
# Out:
# Alexander Valley
# Alexander Valley
# Alexander Valley
# Alexander Valley

# %%
to_append = [5, 6]
df_length = len(soils_df)
soils_df.loc[df_length] = to_append
soils_df
# Out:
#   appellation coordinates
# 0           5           6
# 1           5           6
# 2           5           6

# %%
#app_geo_slice = appellations_geo_df[0:57]

# %%
#print(appellations_geo_df.iloc[0,1])
#appellations_geo_df.iloc[[0,1]
# Out:
# 32

# %%
print(appellations_geo_df.loc[[0][0:1]])
# Out:
#         appellation  count  app_lat   app_lon
# 0  Alexander Valley     32   38.613 -122.7694

# %%
for i in range(len(appellations_geo_df)):
    print(appellations_geo_df.iloc[i,0])
# Out:
# Alexander Valley
# Amador County
# Anderson Valley
# Atlas Peak
# Bennett Valley
# California
# Calistoga
# Carneros
# Chalk Hill
# Chehalem Mountains
# Columbia Valley
# Coombsville
# Diamond Mountain District
# Dry Creek Valley
# Dundee Hills
# Eola-Amity Hills
# Green Valley
# Horse Heaven Hills
# Howell Mountain
# Knights Valley
# Los Carneros
# Mendocino County
# Mendocino Ridge
# Monterey
# Monticello
# Mount Harlan
# Mount Veeder
# Napa County
# Napa Valley
# North Coast
# Oak Knoll District
# Oakville
# Oregon
# Paso Robles
# Red Mountain
# Ribbon Ridge
# Russian River Valley
# Rutherford
# San Luis Obispo County
# Santa Cruz Mountains
# Santa Lucia Highlands
# Santa Maria Valley
# Santa Ynez Valley
# Sierra Foothills
# Snipes Mountain
# Sonoma Coast
# Sonoma County
# Sonoma Mountain
# Sonoma Valley
# Spring Mountain District
# St Helena
# Sta Rita Hills
# Stags Leap District
# Walla Walla Valley
# Washington
# Willamette Valley
# Yakima Valley
# Yountville

# %%
# Initialize DF via looping through json
appLon = appellations_geo_df.iloc[0,3]
appLat = appellations_geo_df.iloc[0, 2]
url = f'https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon={appLon}&lat={appLat}&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty'
appellation_sample = requests.get(url).json()
appellation_sample

soils_df: pd.DataFrame = []
#pd.DataFrame(columns = ['appellation', 'coordinates']) 
soils_df

# Get column name
for i in range(len(appellation_sample['properties']['layers'])):
    for j in range(len(appellation_sample['properties']['layers'][0]['depths'])):
        print(f"{appellation_sample['properties']['layers'][i]['name']}_{appellation_soil_json['properties']['layers'][i]['depths'][j]['label']}")
# Out:
# bdod_0-5cm
# bdod_5-15cm
# bdod_15-30cm
# bdod_30-60cm
# bdod_60-100cm
# bdod_100-200cm
# cec_0-5cm
# cec_5-15cm
# cec_15-30cm
# cec_30-60cm
# cec_60-100cm
# cec_100-200cm
# cfvo_0-5cm
# cfvo_5-15cm
# cfvo_15-30cm
# cfvo_30-60cm
# cfvo_60-100cm
# cfvo_100-200cm
# clay_0-5cm
# clay_5-15cm
# clay_15-30cm
# clay_30-60cm
# clay_60-100cm
# clay_100-200cm
# nitrogen_0-5cm
# nitrogen_5-15cm
# nitrogen_15-30cm
# nitrogen_30-60cm
# nitrogen_60-100cm
# nitrogen_100-200cm
# ocd_0-5cm
# ocd_5-15cm
# ocd_15-30cm
# ocd_30-60cm
# ocd_60-100cm
# ocd_100-200cm
# ocs_0-30cm
# --------------------
# IndexErrorTraceback (most recent call last)
# <ipython-input-74-363b7bbdfa40> in <module>
#      13 for i in range(len(appellation_sample['properties']['layers'])):
#      14     for j in range(len(appellation_sample['properties']['layers'][0]['depths'])):
# ---> 15         print(f"{appellation_sample['properties']['layers'][i]['name']}_{appellation_soil_json['properties']['layers'][i]['depths'][j]['label']}")
#      16
#
# IndexError: list index out of range

# %%
len(appellation_sample['properties']['layers'][0]['depths'])
# Out:
# 6

# %%
# Loop through 
appellation_geo_list = []
for i in range(len(appellations_geo_df)):
    appLon = appellations_geo_df.iloc[i,3]
    appLat = appellations_geo_df.iloc[i, 2]
    #appellation_geo = f'lon={app_lon}&lat={app_lat}'
    #appellation_geo = f'lon={appellations_geo_df['app_lon']}&lat={appellations_geo_df['app_lat']}'
    url = f'https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon={appLon}&lat={appLat}&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty'
    to_append = [5, 6]
    df_length = len(soils_df)
    soils_df.loc[df_length] = to_append
# Out:
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.7694&lat=38.613&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.7741&lat=38.3489&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.2978&lat=40.4482&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.2559&lat=38.3195&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.6767&lat=38.4405&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=nan&lat=nan&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.5797&lat=38.5788&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.3325&lat=38.2554&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.7772&lat=38.6038&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-123.0373&lat=45.3762&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-119.2883&lat=47.1211&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.2444&lat=38.305&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.5396&lat=38.5506&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.9666&lat=38.6999&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-123.0125&lat=45.2762&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-123.116&lat=45.056000000000004&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.9&lat=38.42&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-119.8678&lat=46.1332&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.4584&lat=38.5765&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.6833&lat=38.6333&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.3422&lat=38.2647&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-123.4384&lat=39.55&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-123.6456&lat=39.1345&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-121.32700000000001&lat=36.4334&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=nan&lat=nan&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-121.3695&lat=36.7363&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.4478&lat=38.3794&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.2654&lat=38.5025&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.2654&lat=38.5025&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=nan&lat=nan&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.3339&lat=38.3583&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.4028&lat=38.4367&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=nan&lat=nan&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.6545&lat=35.6369&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-119.4409&lat=46.2979&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-123.0944&lat=45.3594&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.8175&lat=38.4836&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.4226&lat=38.4591&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.6596&lat=35.2828&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-121.8449&lat=37.1109&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-121.4848&lat=36.4469&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.3481&lat=34.8123&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.0974&lat=34.5842&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.4736&lat=38.0902&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.008&lat=46.3285&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.9755&lat=38.3641&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.9888&lat=38.578&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.575&lat=38.323&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.4975&lat=38.3669&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.5494&lat=38.5325&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.4704&lat=38.5052&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.1152&lat=34.666&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.3213&lat=38.4141&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=118.5&lat=46.0&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=nan&lat=nan&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.9338&lat=44.9426&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-120.0086&lat=46.3289&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty
# https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.3608&lat=38.4016&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty

# %%
# Create API call
appellation_geo = 'lon=-122.2654&lat=38.5025'
url = f'https://rest.soilgrids.org/soilgrids/v2.0/properties/query?{appellation_geo}&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty'
url
# Out:
# 'https://rest.soilgrids.org/soilgrids/v2.0/properties/query?lon=-122.2654&lat=38.5025&property=bdod&property=cec&property=cfvo&property=clay&property=nitrogen&property=ocd&property=ocs&property=phh2o&property=sand&property=silt&property=soc&depth=0-5cm&depth=0-30cm&depth=5-15cm&depth=15-30cm&depth=30-60cm&depth=60-100cm&depth=100-200cm&value=Q0.5&value=Q0.05&value=Q0.95&value=mean&value=uncertainty'

# %%
appellation_soil = requests.get(url)
appellation_soil
# Out:
# <Response [200]>

# %%
appellation_soil.json()
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-122.2654, 38.5025]},
#  'properties': {'layers': [{'name': 'bdod',
#     'unit_measure': {'d_factor': 100,
#      'mapped_units': 'cg/cm³',
#      'target_units': 'kg/dm³',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 62,
#        'Q0.5': 110,
#        'Q0.95': 168,
#        'mean': 113,
#        'uncertainty': 10}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 70,
#        'Q0.5': 120,
#        'Q0.95': 171,
#        'mean': 124,
#        'uncertainty': 8}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 88,
#        'Q0.5': 130,
#        'Q0.95': 177,
#        'mean': 132,
#        'uncertainty': 7}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 114,
#        'Q0.5': 146,
#        'Q0.95': 194,
#        'mean': 148,
#        'uncertainty': 5}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 108,
#        'Q0.5': 150,
#        'Q0.95': 190,
#        'mean': 149,
#        'uncertainty': 5}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 108,
#        'Q0.5': 150,
#        'Q0.95': 198,
#        'mean': 150,
#        'uncertainty': 6}}]},
#    {'name': 'cec',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'mmol(c)/kg',
#      'target_units': 'cmol(c)/kg',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 93,
#        'Q0.5': 294,
#        'Q0.95': 499,
#        'mean': 291,
#        'uncertainty': 14}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 86,
#        'Q0.5': 287,
#        'Q0.95': 495,
#        'mean': 274,
#        'uncertainty': 14}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 83,
#        'Q0.5': 288,
#        'Q0.95': 480,
#        'mean': 270,
#        'uncertainty': 14}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 82,
#        'Q0.5': 296,
#        'Q0.95': 471,
#        'mean': 277,
#        'uncertainty': 13}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 82,
#        'Q0.5': 287,
#        'Q0.95': 453,
#        'mean': 279,
#        'uncertainty': 13}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 86,
#        'Q0.5': 289,
#        'Q0.95': 426,
#        'mean': 279,
#        'uncertainty': 12}}]},
#    {'name': 'cfvo',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'cm³/dm³',
#      'target_units': 'cm³/100cm³',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 10,
#        'Q0.5': 145,
#        'Q0.95': 400,
#        'mean': 160,
#        'uncertainty': 27}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 10,
#        'Q0.5': 155,
#        'Q0.95': 440,
#        'mean': 172,
#        'uncertainty': 28}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 145,
#        'Q0.95': 421,
#        'mean': 166,
#        'uncertainty': 29}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 150,
#        'Q0.95': 504,
#        'mean': 189,
#        'uncertainty': 34}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 160,
#        'Q0.95': 500,
#        'mean': 193,
#        'uncertainty': 31}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 150,
#        'Q0.95': 550,
#        'mean': 186,
#        'uncertainty': 37}}]},
#    {'name': 'clay',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'g/kg',
#      'target_units': '%',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 37,
#        'Q0.5': 214,
#        'Q0.95': 720,
#        'mean': 286,
#        'uncertainty': 32}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 46,
#        'Q0.5': 222,
#        'Q0.95': 749,
#        'mean': 298,
#        'uncertainty': 32}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 44,
#        'Q0.5': 275,
#        'Q0.95': 763,
#        'mean': 341,
#        'uncertainty': 26}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 41,
#        'Q0.5': 308,
#        'Q0.95': 786,
#        'mean': 360,
#        'uncertainty': 24}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 45,
#        'Q0.5': 290,
#        'Q0.95': 773,
#        'mean': 348,
#        'uncertainty': 25}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 31,
#        'Q0.5': 273,
#        'Q0.95': 761,
#        'mean': 339,
#        'uncertainty': 27}}]},
#    {'name': 'nitrogen',
#     'unit_measure': {'d_factor': 100,
#      'mapped_units': 'cg/kg',
#      'target_units': 'g/kg',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 77,
#        'Q0.5': 243,
#        'Q0.95': 1304,
#        'mean': 459,
#        'uncertainty': 50}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 48,
#        'Q0.5': 115,
#        'Q0.95': 456,
#        'mean': 160,
#        'uncertainty': 35}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 30,
#        'Q0.5': 77,
#        'Q0.95': 231,
#        'mean': 98,
#        'uncertainty': 26}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 16,
#        'Q0.5': 62,
#        'Q0.95': 231,
#        'mean': 79,
#        'uncertainty': 35}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 4,
#        'Q0.5': 47,
#        'Q0.95': 189,
#        'mean': 68,
#        'uncertainty': 39}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 4,
#        'Q0.5': 40,
#        'Q0.95': 145,
#        'mean': 60,
#        'uncertainty': 35}}]},
#    {'name': 'ocd',
#     'unit_measure': {'d_factor': 1000,
#      'mapped_units': 'g/dm³',
#      'target_units': 'kg/dm³',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 178,
#        'Q0.5': 330,
#        'Q0.95': 707,
#        'mean': 381,
#        'uncertainty': 16}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 107,
#        'Q0.5': 215,
#        'Q0.95': 423,
#        'mean': 254,
#        'uncertainty': 15}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 81,
#        'Q0.5': 156,
#        'Q0.95': 346,
#        'mean': 179,
#        'uncertainty': 17}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 29,
#        'Q0.5': 86,
#        'Q0.95': 271,
#        'mean': 103,
#        'uncertainty': 28}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 15,
#        'Q0.5': 55,
#        'Q0.95': 190,
#        'mean': 73,
#        'uncertainty': 32}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 13,
#        'Q0.5': 31,
#        'Q0.95': 119,
#        'mean': 44,
#        'uncertainty': 34}}]},
#    {'name': 'ocs',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 't/ha',
#      'target_units': 'kg/m²',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 30,
#        'unit_depth': 'cm'},
#       'label': '0-30cm',
#       'values': {'Q0.05': 16,
#        'Q0.5': 45,
#        'Q0.95': 107,
#        'mean': 54,
#        'uncertainty': 20}}]},
#    {'name': 'phh2o',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'pH*10',
#      'target_units': '-',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 52,
#        'Q0.5': 62,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 4}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 52,
#        'Q0.5': 63,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 4}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 54,
#        'Q0.5': 62,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 3}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 54,
#        'Q0.5': 62,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 3}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 53,
#        'Q0.5': 63,
#        'Q0.95': 78,
#        'mean': 64,
#        'uncertainty': 4}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 53,
#        'Q0.5': 64,
#        'Q0.95': 80,
#        'mean': 65,
#        'uncertainty': 4}}]},
#    {'name': 'sand',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'g/kg',
#      'target_units': '%',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 86,
#        'Q0.5': 222,
#        'Q0.95': 542,
#        'mean': 264,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 77,
#        'Q0.5': 214,
#        'Q0.95': 528,
#        'mean': 257,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 72,
#        'Q0.5': 198,
#        'Q0.95': 504,
#        'mean': 239,
#        'uncertainty': 22}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 65,
#        'Q0.5': 200,
#        'Q0.95': 476,
#        'mean': 234,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 71,
#        'Q0.5': 202,
#        'Q0.95': 497,
#        'mean': 238,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 69,
#        'Q0.5': 191,
#        'Q0.95': 571,
#        'mean': 244,
#        'uncertainty': 26}}]},
#    {'name': 'silt',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'g/kg',
#      'target_units': '%',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 102,
#        'Q0.5': 450,
#        'Q0.95': 807,
#        'mean': 450,
#        'uncertainty': 16}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 100,
#        'Q0.5': 455,
#        'Q0.95': 804,
#        'mean': 445,
#        'uncertainty': 15}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 75,
#        'Q0.5': 419,
#        'Q0.95': 803,
#        'mean': 420,
#        'uncertainty': 17}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 67,
#        'Q0.5': 400,
#        'Q0.95': 779,
#        'mean': 406,
#        'uncertainty': 18}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 54,
#        'Q0.5': 420,
#        'Q0.95': 765,
#        'mean': 414,
#        'uncertainty': 17}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 51,
#        'Q0.5': 410,
#        'Q0.95': 803,
#        'mean': 417,
#        'uncertainty': 18}}]},
#    {'name': 'soc',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'dg/kg',
#      'target_units': 'g/kg',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 105,
#        'Q0.5': 308,
#        'Q0.95': 1042,
#        'mean': 419,
#        'uncertainty': 30}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 65,
#        'Q0.5': 202,
#        'Q0.95': 661,
#        'mean': 253,
#        'uncertainty': 30}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 42,
#        'Q0.5': 98,
#        'Q0.95': 243,
#        'mean': 118,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 18,
#        'Q0.5': 55,
#        'Q0.95': 279,
#        'mean': 82,
#        'uncertainty': 47}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 9,
#        'Q0.5': 43,
#        'Q0.95': 152,
#        'mean': 56,
#        'uncertainty': 33}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 4,
#        'Q0.5': 27,
#        'Q0.95': 110,
#        'mean': 43,
#        'uncertainty': 39}}]}]},
#  'query_time_s': 21.186112880706787}

# %%
appellation_soil_json = appellation_soil.json()

# %%
appellation_soil_json
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-122.2654, 38.5025]},
#  'properties': {'layers': [{'name': 'bdod',
#     'unit_measure': {'d_factor': 100,
#      'mapped_units': 'cg/cm³',
#      'target_units': 'kg/dm³',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 62,
#        'Q0.5': 110,
#        'Q0.95': 168,
#        'mean': 113,
#        'uncertainty': 10}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 70,
#        'Q0.5': 120,
#        'Q0.95': 171,
#        'mean': 124,
#        'uncertainty': 8}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 88,
#        'Q0.5': 130,
#        'Q0.95': 177,
#        'mean': 132,
#        'uncertainty': 7}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 114,
#        'Q0.5': 146,
#        'Q0.95': 194,
#        'mean': 148,
#        'uncertainty': 5}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 108,
#        'Q0.5': 150,
#        'Q0.95': 190,
#        'mean': 149,
#        'uncertainty': 5}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 108,
#        'Q0.5': 150,
#        'Q0.95': 198,
#        'mean': 150,
#        'uncertainty': 6}}]},
#    {'name': 'cec',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'mmol(c)/kg',
#      'target_units': 'cmol(c)/kg',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 93,
#        'Q0.5': 294,
#        'Q0.95': 499,
#        'mean': 291,
#        'uncertainty': 14}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 86,
#        'Q0.5': 287,
#        'Q0.95': 495,
#        'mean': 274,
#        'uncertainty': 14}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 83,
#        'Q0.5': 288,
#        'Q0.95': 480,
#        'mean': 270,
#        'uncertainty': 14}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 82,
#        'Q0.5': 296,
#        'Q0.95': 471,
#        'mean': 277,
#        'uncertainty': 13}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 82,
#        'Q0.5': 287,
#        'Q0.95': 453,
#        'mean': 279,
#        'uncertainty': 13}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 86,
#        'Q0.5': 289,
#        'Q0.95': 426,
#        'mean': 279,
#        'uncertainty': 12}}]},
#    {'name': 'cfvo',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'cm³/dm³',
#      'target_units': 'cm³/100cm³',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 10,
#        'Q0.5': 145,
#        'Q0.95': 400,
#        'mean': 160,
#        'uncertainty': 27}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 10,
#        'Q0.5': 155,
#        'Q0.95': 440,
#        'mean': 172,
#        'uncertainty': 28}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 145,
#        'Q0.95': 421,
#        'mean': 166,
#        'uncertainty': 29}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 150,
#        'Q0.95': 504,
#        'mean': 189,
#        'uncertainty': 34}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 160,
#        'Q0.95': 500,
#        'mean': 193,
#        'uncertainty': 31}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 0,
#        'Q0.5': 150,
#        'Q0.95': 550,
#        'mean': 186,
#        'uncertainty': 37}}]},
#    {'name': 'clay',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'g/kg',
#      'target_units': '%',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 37,
#        'Q0.5': 214,
#        'Q0.95': 720,
#        'mean': 286,
#        'uncertainty': 32}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 46,
#        'Q0.5': 222,
#        'Q0.95': 749,
#        'mean': 298,
#        'uncertainty': 32}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 44,
#        'Q0.5': 275,
#        'Q0.95': 763,
#        'mean': 341,
#        'uncertainty': 26}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 41,
#        'Q0.5': 308,
#        'Q0.95': 786,
#        'mean': 360,
#        'uncertainty': 24}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 45,
#        'Q0.5': 290,
#        'Q0.95': 773,
#        'mean': 348,
#        'uncertainty': 25}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 31,
#        'Q0.5': 273,
#        'Q0.95': 761,
#        'mean': 339,
#        'uncertainty': 27}}]},
#    {'name': 'nitrogen',
#     'unit_measure': {'d_factor': 100,
#      'mapped_units': 'cg/kg',
#      'target_units': 'g/kg',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 77,
#        'Q0.5': 243,
#        'Q0.95': 1304,
#        'mean': 459,
#        'uncertainty': 50}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 48,
#        'Q0.5': 115,
#        'Q0.95': 456,
#        'mean': 160,
#        'uncertainty': 35}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 30,
#        'Q0.5': 77,
#        'Q0.95': 231,
#        'mean': 98,
#        'uncertainty': 26}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 16,
#        'Q0.5': 62,
#        'Q0.95': 231,
#        'mean': 79,
#        'uncertainty': 35}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 4,
#        'Q0.5': 47,
#        'Q0.95': 189,
#        'mean': 68,
#        'uncertainty': 39}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 4,
#        'Q0.5': 40,
#        'Q0.95': 145,
#        'mean': 60,
#        'uncertainty': 35}}]},
#    {'name': 'ocd',
#     'unit_measure': {'d_factor': 1000,
#      'mapped_units': 'g/dm³',
#      'target_units': 'kg/dm³',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 178,
#        'Q0.5': 330,
#        'Q0.95': 707,
#        'mean': 381,
#        'uncertainty': 16}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 107,
#        'Q0.5': 215,
#        'Q0.95': 423,
#        'mean': 254,
#        'uncertainty': 15}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 81,
#        'Q0.5': 156,
#        'Q0.95': 346,
#        'mean': 179,
#        'uncertainty': 17}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 29,
#        'Q0.5': 86,
#        'Q0.95': 271,
#        'mean': 103,
#        'uncertainty': 28}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 15,
#        'Q0.5': 55,
#        'Q0.95': 190,
#        'mean': 73,
#        'uncertainty': 32}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 13,
#        'Q0.5': 31,
#        'Q0.95': 119,
#        'mean': 44,
#        'uncertainty': 34}}]},
#    {'name': 'ocs',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 't/ha',
#      'target_units': 'kg/m²',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 30,
#        'unit_depth': 'cm'},
#       'label': '0-30cm',
#       'values': {'Q0.05': 16,
#        'Q0.5': 45,
#        'Q0.95': 107,
#        'mean': 54,
#        'uncertainty': 20}}]},
#    {'name': 'phh2o',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'pH*10',
#      'target_units': '-',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 52,
#        'Q0.5': 62,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 4}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 52,
#        'Q0.5': 63,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 4}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 54,
#        'Q0.5': 62,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 3}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 54,
#        'Q0.5': 62,
#        'Q0.95': 75,
#        'mean': 63,
#        'uncertainty': 3}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 53,
#        'Q0.5': 63,
#        'Q0.95': 78,
#        'mean': 64,
#        'uncertainty': 4}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 53,
#        'Q0.5': 64,
#        'Q0.95': 80,
#        'mean': 65,
#        'uncertainty': 4}}]},
#    {'name': 'sand',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'g/kg',
#      'target_units': '%',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 86,
#        'Q0.5': 222,
#        'Q0.95': 542,
#        'mean': 264,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 77,
#        'Q0.5': 214,
#        'Q0.95': 528,
#        'mean': 257,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 72,
#        'Q0.5': 198,
#        'Q0.95': 504,
#        'mean': 239,
#        'uncertainty': 22}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 65,
#        'Q0.5': 200,
#        'Q0.95': 476,
#        'mean': 234,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 71,
#        'Q0.5': 202,
#        'Q0.95': 497,
#        'mean': 238,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 69,
#        'Q0.5': 191,
#        'Q0.95': 571,
#        'mean': 244,
#        'uncertainty': 26}}]},
#    {'name': 'silt',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'g/kg',
#      'target_units': '%',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 102,
#        'Q0.5': 450,
#        'Q0.95': 807,
#        'mean': 450,
#        'uncertainty': 16}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 100,
#        'Q0.5': 455,
#        'Q0.95': 804,
#        'mean': 445,
#        'uncertainty': 15}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 75,
#        'Q0.5': 419,
#        'Q0.95': 803,
#        'mean': 420,
#        'uncertainty': 17}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 67,
#        'Q0.5': 400,
#        'Q0.95': 779,
#        'mean': 406,
#        'uncertainty': 18}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 54,
#        'Q0.5': 420,
#        'Q0.95': 765,
#        'mean': 414,
#        'uncertainty': 17}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 51,
#        'Q0.5': 410,
#        'Q0.95': 803,
#        'mean': 417,
#        'uncertainty': 18}}]},
#    {'name': 'soc',
#     'unit_measure': {'d_factor': 10,
#      'mapped_units': 'dg/kg',
#      'target_units': 'g/kg',
#      'uncertainty_unit': ''},
#     'depths': [{'range': {'top_depth': 0,
#        'bottom_depth': 5,
#        'unit_depth': 'cm'},
#       'label': '0-5cm',
#       'values': {'Q0.05': 105,
#        'Q0.5': 308,
#        'Q0.95': 1042,
#        'mean': 419,
#        'uncertainty': 30}},
#      {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#       'label': '5-15cm',
#       'values': {'Q0.05': 65,
#        'Q0.5': 202,
#        'Q0.95': 661,
#        'mean': 253,
#        'uncertainty': 30}},
#      {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#       'label': '15-30cm',
#       'values': {'Q0.05': 42,
#        'Q0.5': 98,
#        'Q0.95': 243,
#        'mean': 118,
#        'uncertainty': 21}},
#      {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#       'label': '30-60cm',
#       'values': {'Q0.05': 18,
#        'Q0.5': 55,
#        'Q0.95': 279,
#        'mean': 82,
#        'uncertainty': 47}},
#      {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#       'label': '60-100cm',
#       'values': {'Q0.05': 9,
#        'Q0.5': 43,
#        'Q0.95': 152,
#        'mean': 56,
#        'uncertainty': 33}},
#      {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#       'label': '100-200cm',
#       'values': {'Q0.05': 4,
#        'Q0.5': 27,
#        'Q0.95': 110,
#        'mean': 43,
#        'uncertainty': 39}}]}]},
#  'query_time_s': 21.186112880706787}

# %%
# Get column name A
#appellation_soil_json['properties']['layers'][0]['name']['depths'][0]['label']
# Get column name B
#appellation_soil_json['properties']['layers'][0]['depths'][0]['label']

# Get bdod
#appellation_soil_json['properties']['layers'][0]['depths'][0]['values']['Q0.5']#['values']['Q0.5']
# Out:
# '0-5cm'

# %%
appellation_soil_json['properties']['layers'][1]['depths']
#['values']['Q0.5']
# Out:
# [{'range': {'top_depth': 0, 'bottom_depth': 5, 'unit_depth': 'cm'},
#   'label': '0-5cm',
#   'values': {'Q0.05': 93,
#    'Q0.5': 294,
#    'Q0.95': 499,
#    'mean': 291,
#    'uncertainty': 14}},
#  {'range': {'top_depth': 5, 'bottom_depth': 15, 'unit_depth': 'cm'},
#   'label': '5-15cm',
#   'values': {'Q0.05': 86,
#    'Q0.5': 287,
#    'Q0.95': 495,
#    'mean': 274,
#    'uncertainty': 14}},
#  {'range': {'top_depth': 15, 'bottom_depth': 30, 'unit_depth': 'cm'},
#   'label': '15-30cm',
#   'values': {'Q0.05': 83,
#    'Q0.5': 288,
#    'Q0.95': 480,
#    'mean': 270,
#    'uncertainty': 14}},
#  {'range': {'top_depth': 30, 'bottom_depth': 60, 'unit_depth': 'cm'},
#   'label': '30-60cm',
#   'values': {'Q0.05': 82,
#    'Q0.5': 296,
#    'Q0.95': 471,
#    'mean': 277,
#    'uncertainty': 13}},
#  {'range': {'top_depth': 60, 'bottom_depth': 100, 'unit_depth': 'cm'},
#   'label': '60-100cm',
#   'values': {'Q0.05': 82,
#    'Q0.5': 287,
#    'Q0.95': 453,
#    'mean': 279,
#    'uncertainty': 13}},
#  {'range': {'top_depth': 100, 'bottom_depth': 200, 'unit_depth': 'cm'},
#   'label': '100-200cm',
#   'values': {'Q0.05': 86,
#    'Q0.5': 289,
#    'Q0.95': 426,
#    'mean': 279,
#    'uncertainty': 12}}]
