# %%
# Import the requests library.
import requests
import numpy as np
import pandas as pd
# Import the requests library.
import requests
import datetime
from datetime import datetime
import matplotlib.pyplot as plt
# Dependencies for the wine API
import urllib
import json
# Import the API key.
from config import Token_NOAA
from config import API_Token
import calendar
#Suppress Warnings
pd.options.mode.chained_assignment = None  # default='warn'
#Display all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Wine and Weather Data

# %%
temp_df=pd.read_csv('Final_Temp_Weather_API.csv')
prcp_df=pd.read_csv('Final_Prcp_Weather_API.csv')
red_USA_df=pd.read_csv('Red_Wine_USA.csv')
white_USA_df=pd.read_csv('White_Wine_USA.csv')

# %%
calender_years=[1992,1993, 1994, 1995,1996,1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,2013, 2014,2015, 2016, 2017]
calender_months=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %% [markdown]
# # Combine Weather Data and Wine Data

# %%
#Create empty columns to iterate through
for month in calender_months:
    white_USA_df['avgPrcp'+str(month)]=0.00
    white_USA_df['avgTemp'+str(month)]=0
#Combine white wine with avgerage temperature and precipitation data
for i in range(len(white_USA_df)):
    for month in calender_months: 
        for year in calender_years:

            if white_USA_df['vintage'][i]==year:
#------------------------------------------------------------------California-------------------------------------------------- 
                if white_USA_df['appellation'][i]=='Napa Valley' or white_USA_df['appellation'][i]=='Los Carneros' or white_USA_df['appellation'][i]=='Atlas Peak' or white_USA_df['appellation'][i]=='Calistoga' or white_USA_df['appellation'][i]=='Napa County' or white_USA_df['appellation'][i]=='Rutherford' or white_USA_df['appellation'][i]=='Oakville' or white_USA_df['appellation'][i]=='Howell Mountain' or white_USA_df['appellation'][i]=='Stags Leap District' or white_USA_df['appellation'][i]=='St Helena' or white_USA_df['appellation'][i]=='Knights Valley' or white_USA_df['appellation'][i]=='Oak Knoll District' or white_USA_df['appellation'][i]=='Coombsville' or white_USA_df['appellation'][i]=='Spring Mountain District' or white_USA_df['appellation'][i]=='Mount Veeder' or white_USA_df['appellation'][i]=='Yountville' or white_USA_df['appellation'][i]=='Diamond Mountain District' or white_USA_df['appellation'][i]=='Green Valley':
                    try:
                        white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPNapa
                        white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==year].avgTempNapa
                    except:
                        pass
                if white_USA_df['appellation'][i]=='Santa Cruz Mountains' or white_USA_df['appellation'][i]=='Santa Lucia Highlands' or white_USA_df['appellation'][i]=='Santa Ynez Valley' or white_USA_df['appellation'][i]=='St Rita Hills':
                    try:
                        white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPSanta
                        white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempSanta
                    except:
                        pass
                if white_USA_df['appellation'][i]=='Sonoma Coast' or white_USA_df['appellation'][i]=='Chalk Hill' or white_USA_df['appellation'][i]=='Sonoma Valley' or white_USA_df['appellation'][i]=='Bennett Valley' or white_USA_df['appellation'][i]=='Mendocino Ridge' or white_USA_df['appellation'][i]=='Russian River Valley' or white_USA_df['appellation'][i]=='Sonoma Coast' or white_USA_df['appellation'][i]=='Carneros' or white_USA_df['appellation'][i]=='Alexander Valley' or white_USA_df['appellation'][i]=='Dry Creek Valley':
                    try:
                        white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPSonoma
                        white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempSonoma
                    except:
                        pass
#------------------------------------------------------------------Washington--------------------------------------------------
                if white_USA_df['appellation'][i]=='Yakima Valley' or white_USA_df['appellation'][i]=='Horse Heaven Hills' or white_USA_df['appellation'][i]=='Snipes Mountains' or white_USA_df['appellation'][i]=='Red Mountain':
                    try:
                        white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPYakima
                        white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempYakima
                    except:
                        pass
                if white_USA_df['appellation'][i]=='Walla Walla Valley':
                    try:
                        white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPWalla
                        white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempWalla
                    except:
                        pass
                if white_USA_df['appellation'][i]=='Columbia Valley':
                    try:
                        white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPColumbia
                        white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempColumbia
                    except:
                        pass
#------------------------------------------------------------------Oregon--------------------------------------------------
                if white_USA_df['appellation'][i]=='Willamette Valley' or white_USA_df['appellation'][i]=='Dundee Hills' or white_USA_df['appellation'][i]=='Eola-Amity Hills' or white_USA_df['appellation'][i]=='Ribbon Ridge' or white_USA_df['appellation'][i]=='Chehalem Mountains':
                    try:
                        white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPDundee
                        white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempDundee
                    except:
                        pass

# %%
white_USA_df.head(50)
# Out:
#                                                  wine  wine_id  \
# 0   Ridge Vineyards, Monte Bello Chardonnay, White...   120785
# 1   Stags' Leap Winery, Chardonnay, White, Napa Va...   129823
# 2   Joseph Phelps Vineyards, Freestone Chardonnay,...    89569
# 3   Crossbarn By Paul Hobbs, Chardonnay, White, So...    47377
# 4   Mount Eden Vineyards, Chardonnay, White, Santa...   107658
# 5   Paul Hobbs, Chardonnay, White, Russian River V...   113414
# 6   Ridge Vineyards Estate, Chardonnay, White, San...   120758
# 7   Pahlmeyer, Napa Valley Chardonnay, White, Napa...   111897
# 8   Marcassin, Lorenzo Vineyard Chardonnay, White,...   101640
# 9   Marcassin, Lorenzo Vineyard Chardonnay, White,...   101640
# 10         Kongsgaard, Chardonnay, White, Napa Valley    91585
# 11  Peter Michael Winery, L'Apres-Midi Sauvignon B...   114824
# 12  Kongsgaard, The Judge Chardonnay, White, Napa ...    91591
# 13  Aubert Wines, Larry Hyde & Sons Vineyard Chard...     6880
# 14  Peter Michael Winery, Point Rouge Chardonnay, ...   114834
# 15  Aubert Wines, Sugar Shack Estate Chardonnay, W...     6875
# 16  Pahlmeyer, Napa Valley Chardonnay, White, Napa...   111897
# 17  Peter Michael Winery, Ma Belle-Fille Chardonna...   114830
# 18         Kongsgaard, Chardonnay, White, Napa Valley    91585
# 19  Peter Michael Winery, Belle Cote Chardonnay, W...   114819
# 20  Peter Michael Winery, Mon Plaisir Chardonnay, ...   114832
# 21  Martinelli, Lolita Ranch Chardonnay, White, Ru...   102656
# 22        Alpha Omega, Chardonnay, White, Napa Valley     3221
# 23  Peter Michael Winery, Ma Belle-Fille Chardonna...   114830
# 24  Peter Michael Winery, Mon Plaisir Chardonnay, ...   114832
# 25  Peter Michael Winery, Belle Cote Chardonnay, W...   114819
# 26  Peter Michael Winery, La Carriere Chardonnay, ...   114826
# 27  Peter Michael Winery, L'Apres-Midi Sauvignon B...   114824
# 28  Chateau Montelena, Chardonnay, White, Napa Valley    39443
# 29  Evening Land, White Label 'Seven Springs Viney...    71176
# 30  Evening Land, Gold Label Seven Springs Vineyar...    71165
# 31   Spottswoode, Sauvignon Blanc, White, Napa County   129358
# 32  Domaine Serene, Clos Du Soleil Vineyard Chardo...    65489
# 33  Chateau Montelena, Chardonnay, White, Napa Valley    39443
# 34  Stag'S Leap Wine Cellars, Karia Chardonnay, Wh...   129796
# 35  Ferrari-Carano, Dominique Vineyard Chardonnay,...    73116
# 36  Ferrari-Carano, Fiorella Vineyard Chardonnay, ...    73120
# 37  Ferrari-Carano, Emelia'S Cuvee Chardonnay, Whi...    73119
# 38  Ferrari-Carano, Reserve Chardonnay, White, Car...    73129
# 39  Duckhorn Vineyards, Sauvignon Blanc, White, Na...    68067
# 40  Kenefick Ranch, Sauvignon Blanc, White, Napa V...    90640
# 41  Ghost Block, Morgan Lee Vineyard Sauvignon Bla...    78679
# 42  Paul Hobbs, Cuvee Agustina Richard Dinner Vine...   113415
# 43  Paul Hobbs, Edward James Estate Chardonnay, Wh...   113417
# 44  Paul Hobbs, Ross Station Estatechardonnay, Whi...   113427
# 45  Paul Hobbs, Richard Dinner Vineyard Chardonnay...   113425
# 46  Paul Hobbs, Ellen Lane Estate Vineyard Chardon...   113418
# 47  Paul Hobbs, Chardonnay, White, Russian River V...   113414
# 48    Truchard Vineyards, Chardonnay, White, Carneros   136966
# 49  Clos Du Val, Winemaker'S Signature Series Thre...    43845
#
#              appellation  color wine_type     regions country classification  \
# 0   Santa Cruz Mountains  White       dry  California     Usa           None
# 1            Napa Valley  White       dry  California     Usa           None
# 2           Sonoma Coast  White       dry  California     Usa           None
# 3           Sonoma Coast  White       dry  California     Usa           None
# 4   Santa Cruz Mountains  White       dry  California     Usa           None
# 5   Russian River Valley  White       dry  California     Usa           None
# 6   Santa Cruz Mountains  White       dry  California     Usa           None
# 7            Napa Valley  White       dry  California     Usa           None
# 8           Sonoma Coast  White       dry  California     Usa           None
# 9           Sonoma Coast  White       dry  California     Usa           None
# 10           Napa Valley  White       dry  California     Usa           None
# 11        Knights Valley  White       dry  California     Usa           None
# 12           Napa Valley  White       dry  California     Usa           None
# 13              Carneros  White       dry  California     Usa           None
# 14         Sonoma County  White       dry  California     Usa           None
# 15           Napa Valley  White       dry  California     Usa           None
# 16           Napa Valley  White       dry  California     Usa           None
# 17        Knights Valley  White       dry  California     Usa           None
# 18           Napa Valley  White       dry  California     Usa           None
# 19         Sonoma County  White       dry  California     Usa           None
# 20         Sonoma County  White       dry  California     Usa           None
# 21  Russian River Valley  White       dry  California     Usa           None
# 22           Napa Valley  White       dry  California     Usa           None
# 23        Knights Valley  White       dry  California     Usa           None
# 24         Sonoma County  White       dry  California     Usa           None
# 25         Sonoma County  White       dry  California     Usa           None
# 26        Knights Valley  White       dry  California     Usa           None
# 27        Knights Valley  White       dry  California     Usa           None
# 28           Napa Valley  White       dry  California     Usa           None
# 29      Eola-Amity Hills  White       dry      Oregon     Usa           None
# 30      Eola-Amity Hills  White       dry      Oregon     Usa           None
# 31           Napa County  White       dry  California     Usa           None
# 32          Dundee Hills  White       dry      Oregon     Usa           None
# 33           Napa Valley  White       dry  California     Usa           None
# 34           Napa Valley  White       dry  California     Usa           None
# 35  Russian River Valley  White       dry  California     Usa           None
# 36  Russian River Valley  White       dry  California     Usa           None
# 37  Russian River Valley  White       dry  California     Usa           None
# 38              Carneros  White       dry  California     Usa           None
# 39           Napa Valley  White       dry  California     Usa           None
# 40           Napa Valley  White       dry  California     Usa           None
# 41            Yountville  White       dry  California     Usa           None
# 42       Sonoma Mountain  White       dry  California     Usa           None
# 43  Russian River Valley  White       dry  California     Usa           None
# 44  Russian River Valley  White       dry  California     Usa           None
# 45       Sonoma Mountain  White       dry  California     Usa           None
# 46  Russian River Valley  White       dry  California     Usa           None
# 47  Russian River Valley  White       dry  California     Usa           None
# 48              Carneros  White       dry  California     Usa           None
# 49           Napa Valley  White       dry  California     Usa           None
#
#     vintage  is_primeurs  score confidence_index  journalist_count  \
# 0      2016        False  94.39                B                 3
# 1      2016        False  89.83               A+                 3
# 2      2016        False  90.73               C+                 4
# 3      2016        False  90.39               B+                 3
# 4      2015        False  92.22                B                 4
# 5      2016        False  90.39               B+                 3
# 6      2016        False  92.81               A+                 3
# 7      2015        False  92.83               C+                 4
# 8      1993        False  92.07                C                 3
# 9      1998        False  91.74                B                 4
# 10     2016        False  95.52                A                 3
# 11     2016        False  91.44                B                 3
# 12     2015        False  97.27               B+                 4
# 13     2016        False  96.98               B+                 3
# 14     2015        False  95.69               C+                 3
# 15     2016        False  95.57               C+                 3
# 16     2016        False  95.19               A+                 4
# 17     2016        False  95.17                C                 3
# 18     2015        False  94.84                B                 5
# 19     2016        False  94.12                B                 3
# 20     2016        False  94.12                B                 3
# 21     2007        False  91.83                A                 4
# 22     2015        False  91.18                B                 3
# 23     2015        False  94.72                B                 4
# 24     2015        False  93.96               C+                 3
# 25     2015        False  93.31               C+                 4
# 26     2015        False  92.93                B                 4
# 27     2015        False  91.91                A                 5
# 28     2014        False  90.18               B+                 5
# 29     2014        False  94.15                B                 4
# 30     2014        False  92.88               B+                 5
# 31     2016        False  90.82               C+                 3
# 32     2015        False  92.87                B                 3
# 33     2011        False  90.46                B                 4
# 34     2015        False  88.32               B+                 5
# 35     2015        False  89.63               B+                 3
# 36     2015        False  89.22                B                 3
# 37     2015        False  88.67                B                 3
# 38     2015        False  88.07                B                 3
# 39     2016        False  85.94                A                 3
# 40     2016        False  85.63               A+                 3
# 41     2016        False  84.38                C                 3
# 42     2015        False  95.41                B                 3
# 43     2015        False  94.15               B+                 3
# 44     2015        False  93.42                A                 3
# 45     2015        False  93.24                B                 4
# 46     2015        False  93.14               B+                 4
# 47     2015        False  90.97               A+                 3
# 48     2015        False  89.83                A                 3
# 49     2015        False  93.40                B                 3
#
#     avgPrcpJanuary  avgTempJanuary  avgPrcpFebruary  avgTempFebruary  \
# 0         0.347879              53         0.238333               58
# 1         0.389697              49         0.154848               55
# 2         0.360758              56         0.160909               68
# 3         0.360758              56         0.160909               68
# 4         0.347879              53         0.238333               58
# 5         0.360758              56         0.160909               68
# 6         0.347879              53         0.238333               58
# 7         0.389697              50         0.154848               56
# 8         0.360758              56         0.160909               68
# 9         0.360758              56         0.160909               68
# 10        0.389697              49         0.154848               55
# 11        0.389697              49         0.154848               55
# 12        0.389697              50         0.154848               56
# 13        0.360758              56         0.160909               68
# 14        0.000000               0         0.000000                0
# 15        0.389697              49         0.154848               55
# 16        0.389697              49         0.154848               55
# 17        0.389697              49         0.154848               55
# 18        0.389697              50         0.154848               56
# 19        0.000000               0         0.000000                0
# 20        0.000000               0         0.000000                0
# 21        0.360758              56         0.160909               68
# 22        0.389697              50         0.154848               56
# 23        0.389697              50         0.154848               56
# 24        0.000000               0         0.000000                0
# 25        0.000000               0         0.000000                0
# 26        0.389697              50         0.154848               56
# 27        0.389697              50         0.154848               56
# 28        0.389697              50         0.154848               51
# 29        0.428788              43         0.303182               48
# 30        0.428788              43         0.303182               48
# 31        0.389697              49         0.154848               55
# 32        0.428788              43         0.303182               48
# 33        0.389697              47         0.154848               48
# 34        0.389697              50         0.154848               56
# 35        0.360758              56         0.160909               68
# 36        0.360758              56         0.160909               68
# 37        0.360758              56         0.160909               68
# 38        0.360758              56         0.160909               68
# 39        0.389697              49         0.154848               55
# 40        0.389697              49         0.154848               55
# 41        0.389697              49         0.154848               55
# 42        0.000000               0         0.000000                0
# 43        0.360758              56         0.160909               68
# 44        0.360758              56         0.160909               68
# 45        0.000000               0         0.000000                0
# 46        0.360758              56         0.160909               68
# 47        0.360758              56         0.160909               68
# 48        0.360758              56         0.160909               68
# 49        0.389697              50         0.154848               56
#
#     avgPrcpMarch  avgTempMarch  avgPrcpApril  avgTempApril  avgPrcpMay  \
# 0       0.110370            56      0.225657            60    0.038482
# 1       0.100278            55      0.194453            58    0.046021
# 2       0.093009            64      0.105876            71    0.076649
# 3       0.093009            64      0.105876            71    0.076649
# 4       0.110370            56      0.225657            60    0.038482
# 5       0.093009            64      0.105876            71    0.076649
# 6       0.110370            56      0.225657            60    0.038482
# 7       0.100278            57      0.194453            57    0.046021
# 8       0.093009            64      0.105876            71    0.076649
# 9       0.093009            64      0.105876            71    0.076649
# 10      0.100278            55      0.194453            58    0.046021
# 11      0.100278            55      0.194453            58    0.046021
# 12      0.100278            57      0.194453            57    0.046021
# 13      0.093009            64      0.105876            71    0.076649
# 14      0.000000             0      0.000000             0    0.000000
# 15      0.100278            55      0.194453            58    0.046021
# 16      0.100278            55      0.194453            58    0.046021
# 17      0.100278            55      0.194453            58    0.046021
# 18      0.100278            57      0.194453            57    0.046021
# 19      0.000000             0      0.000000             0    0.000000
# 20      0.000000             0      0.000000             0    0.000000
# 21      0.093009            64      0.105876            71    0.076649
# 22      0.100278            57      0.194453            57    0.046021
# 23      0.100278            57      0.194453            57    0.046021
# 24      0.000000             0      0.000000             0    0.000000
# 25      0.000000             0      0.000000             0    0.000000
# 26      0.100278            57      0.194453            57    0.046021
# 27      0.100278            57      0.194453            57    0.046021
# 28      0.100278            57      0.194453            59    0.046021
# 29      0.348750            49      0.304927            55    0.121885
# 30      0.348750            49      0.304927            55    0.121885
# 31      0.100278            55      0.194453            58    0.046021
# 32      0.348750            49      0.304927            55    0.121885
# 33      0.100278            50      0.194453            55    0.046021
# 34      0.100278            57      0.194453            57    0.046021
# 35      0.093009            64      0.105876            71    0.076649
# 36      0.093009            64      0.105876            71    0.076649
# 37      0.093009            64      0.105876            71    0.076649
# 38      0.093009            64      0.105876            71    0.076649
# 39      0.100278            55      0.194453            58    0.046021
# 40      0.100278            55      0.194453            58    0.046021
# 41      0.100278            55      0.194453            58    0.046021
# 42      0.000000             0      0.000000             0    0.000000
# 43      0.093009            64      0.105876            71    0.076649
# 44      0.093009            64      0.105876            71    0.076649
# 45      0.000000             0      0.000000             0    0.000000
# 46      0.093009            64      0.105876            71    0.076649
# 47      0.093009            64      0.105876            71    0.076649
# 48      0.093009            64      0.105876            71    0.076649
# 49      0.100278            57      0.194453            57    0.046021
#
#     avgTempMay  avgPrcpJune  avgTempJune  avgPrcpJuly  avgTempJuly  \
# 0           60     0.000000           63     0.000645           63
# 1           61     0.000000           66     0.000000           66
# 2           75     0.000000           84     0.000000           86
# 3           75     0.000000           84     0.000000           86
# 4           60     0.000000           63     0.000645           63
# 5           75     0.000000           84     0.000000           86
# 6           60     0.000000           63     0.000645           63
# 7           60     0.000000           65     0.000000           69
# 8           75     0.000000           84     0.000000           86
# 9           75     0.000000           84     0.000000           86
# 10          61     0.000000           66     0.000000           66
# 11          61     0.000000           66     0.000000           66
# 12          60     0.000000           65     0.000000           69
# 13          75     0.000000           84     0.000000           86
# 14           0     0.000000            0     0.000000            0
# 15          61     0.000000           66     0.000000           66
# 16          61     0.000000           66     0.000000           66
# 17          61     0.000000           66     0.000000           66
# 18          60     0.000000           65     0.000000           69
# 19           0     0.000000            0     0.000000            0
# 20           0     0.000000            0     0.000000            0
# 21          75     0.000000           84     0.000000           86
# 22          60     0.000000           65     0.000000           69
# 23          60     0.000000           65     0.000000           69
# 24           0     0.000000            0     0.000000            0
# 25           0     0.000000            0     0.000000            0
# 26          60     0.000000           65     0.000000           69
# 27          60     0.000000           65     0.000000           69
# 28          63     0.000000           65     0.000000           68
# 29          60     0.144375           65     0.003226           68
# 30          60     0.144375           65     0.003226           68
# 31          61     0.000000           66     0.000000           66
# 32          60     0.144375           65     0.003226           68
# 33          57     0.000000           62     0.000000           65
# 34          60     0.000000           65     0.000000           69
# 35          75     0.000000           84     0.000000           86
# 36          75     0.000000           84     0.000000           86
# 37          75     0.000000           84     0.000000           86
# 38          75     0.000000           84     0.000000           86
# 39          61     0.000000           66     0.000000           66
# 40          61     0.000000           66     0.000000           66
# 41          61     0.000000           66     0.000000           66
# 42           0     0.000000            0     0.000000            0
# 43          75     0.000000           84     0.000000           86
# 44          75     0.000000           84     0.000000           86
# 45           0     0.000000            0     0.000000            0
# 46          75     0.000000           84     0.000000           86
# 47          75     0.000000           84     0.000000           86
# 48          75     0.000000           84     0.000000           86
# 49          60     0.000000           65     0.000000           69
#
#     avgPrcpAugust  avgTempAugust  avgPrcpSeptember  avgTempSeptember  \
# 0        0.000968             64          0.000333                64
# 1        0.000000             65          0.000000                65
# 2        0.000000             83          0.000000                83
# 3        0.000000             83          0.000000                83
# 4        0.000968             64          0.000333                64
# 5        0.000000             83          0.000000                83
# 6        0.000968             64          0.000333                64
# 7        0.000000             69          0.000000                68
# 8        0.000000             83          0.000000                83
# 9        0.000000             83          0.000000                83
# 10       0.000000             65          0.000000                65
# 11       0.000000             65          0.000000                65
# 12       0.000000             69          0.000000                68
# 13       0.000000             83          0.000000                83
# 14       0.000000              0          0.000000                 0
# 15       0.000000             65          0.000000                65
# 16       0.000000             65          0.000000                65
# 17       0.000000             65          0.000000                65
# 18       0.000000             69          0.000000                68
# 19       0.000000              0          0.000000                 0
# 20       0.000000              0          0.000000                 0
# 21       0.000000             83          0.000000                83
# 22       0.000000             69          0.000000                68
# 23       0.000000             69          0.000000                68
# 24       0.000000              0          0.000000                 0
# 25       0.000000              0          0.000000                 0
# 26       0.000000             69          0.000000                68
# 27       0.000000             69          0.000000                68
# 28       0.000000             67          0.000000                66
# 29       0.000000             71          0.079333                61
# 30       0.000000             71          0.079333                61
# 31       0.000000             65          0.000000                65
# 32       0.000000             71          0.079333                61
# 33       0.000000             65          0.000000                66
# 34       0.000000             69          0.000000                68
# 35       0.000000             83          0.000000                83
# 36       0.000000             83          0.000000                83
# 37       0.000000             83          0.000000                83
# 38       0.000000             83          0.000000                83
# 39       0.000000             65          0.000000                65
# 40       0.000000             65          0.000000                65
# 41       0.000000             65          0.000000                65
# 42       0.000000              0          0.000000                 0
# 43       0.000000             83          0.000000                83
# 44       0.000000             83          0.000000                83
# 45       0.000000              0          0.000000                 0
# 46       0.000000             83          0.000000                83
# 47       0.000000             83          0.000000                83
# 48       0.000000             83          0.000000                83
# 49       0.000000             69          0.000000                68
#
#     avgPrcpOctober  avgTempOctober  avgPrcpNovember  avgTempNovember  \
# 0         0.195170              62         0.248669               58
# 1         0.216648              60         0.197567               55
# 2         0.245455              72         0.173840               65
# 3         0.245455              72         0.173840               65
# 4         0.195170              62         0.248669               58
# 5         0.245455              72         0.173840               65
# 6         0.195170              62         0.248669               58
# 7         0.216648              65         0.197567               52
# 8         0.245455              72         0.173840               65
# 9         0.245455              72         0.173840               65
# 10        0.216648              60         0.197567               55
# 11        0.216648              60         0.197567               55
# 12        0.216648              65         0.197567               52
# 13        0.245455              72         0.173840               65
# 14        0.000000               0         0.000000                0
# 15        0.216648              60         0.197567               55
# 16        0.216648              60         0.197567               55
# 17        0.216648              60         0.197567               55
# 18        0.216648              65         0.197567               52
# 19        0.000000               0         0.000000                0
# 20        0.000000               0         0.000000                0
# 21        0.245455              72         0.173840               65
# 22        0.216648              65         0.197567               52
# 23        0.216648              65         0.197567               52
# 24        0.000000               0         0.000000                0
# 25        0.000000               0         0.000000                0
# 26        0.216648              65         0.197567               52
# 27        0.216648              65         0.197567               52
# 28        0.216648              64         0.197567               55
# 29        0.472159              55         0.407605               51
# 30        0.472159              55         0.407605               51
# 31        0.216648              60         0.197567               55
# 32        0.472159              55         0.407605               51
# 33        0.216648              62         0.197567               50
# 34        0.216648              65         0.197567               52
# 35        0.245455              72         0.173840               65
# 36        0.245455              72         0.173840               65
# 37        0.245455              72         0.173840               65
# 38        0.245455              72         0.173840               65
# 39        0.216648              60         0.197567               55
# 40        0.216648              60         0.197567               55
# 41        0.216648              60         0.197567               55
# 42        0.000000               0         0.000000                0
# 43        0.245455              72         0.173840               65
# 44        0.245455              72         0.173840               65
# 45        0.000000               0         0.000000                0
# 46        0.245455              72         0.173840               65
# 47        0.245455              72         0.173840               65
# 48        0.245455              72         0.173840               65
# 49        0.216648              65         0.197567               52
#
#     avgPrcpDecember  avgTempDecember
# 0            0.1755               50
# 1            0.1530               45
# 2            0.1910               57
# 3            0.1910               57
# 4            0.1755               50
# 5            0.1910               57
# 6            0.1755               50
# 7            0.1530               45
# 8            0.1910               57
# 9            0.1910               57
# 10           0.1530               45
# 11           0.1530               45
# 12           0.1530               45
# 13           0.1910               57
# 14           0.0000                0
# 15           0.1530               45
# 16           0.1530               45
# 17           0.1530               45
# 18           0.1530               45
# 19           0.0000                0
# 20           0.0000                0
# 21           0.1910               57
# 22           0.1530               45
# 23           0.1530               45
# 24           0.0000                0
# 25           0.0000                0
# 26           0.1530               45
# 27           0.1530               45
# 28           0.1530               52
# 29           0.1595               36
# 30           0.1595               36
# 31           0.1530               45
# 32           0.1595               36
# 33           0.1530               47
# 34           0.1530               45
# 35           0.1910               57
# 36           0.1910               57
# 37           0.1910               57
# 38           0.1910               57
# 39           0.1530               45
# 40           0.1530               45
# 41           0.1530               45
# 42           0.0000                0
# 43           0.1910               57
# 44           0.1910               57
# 45           0.0000                0
# 46           0.1910               57
# 47           0.1910               57
# 48           0.1910               57
# 49           0.1530               45

# %%
print(white_USA_df.isnull().sum())
# Out:
# wine                  0
# wine_id               0
# appellation           0
# color                 0
# wine_type             0
# regions               0
# country               0
# classification      784
# vintage               0
# is_primeurs           0
# score                 0
# confidence_index      0
# journalist_count      0
# avgPrcpJanuary        0
# avgTempJanuary        0
# avgPrcpFebruary       0
# avgTempFebruary       0
# avgPrcpMarch          0
# avgTempMarch          0
# avgPrcpApril          0
# avgTempApril          0
# avgPrcpMay            0
# avgTempMay            0
# avgPrcpJune           0
# avgTempJune           0
# avgPrcpJuly           0
# avgTempJuly           0
# avgPrcpAugust         0
# avgTempAugust         0
# avgPrcpSeptember      0
# avgTempSeptember      0
# avgPrcpOctober        0
# avgTempOctober        0
# avgPrcpNovember       0
# avgTempNovember       0
# avgPrcpDecember       0
# avgTempDecember       0
# dtype: int64

# %%
white_USA_df.to_csv('Final_White_Temp_Prcp.csv')

# %% [markdown]
# # Practice

# %%
# #Create empty columns to iterate through
# for month in calender_months:
#     white_USA_df['avgTemp'+str(month)]=0.00
# #Combine white wine with avgerage temperature and precipitation data
# for i in range(len(white_USA_df)):
#     for month, year in zip(calender_months,calender_years): 
# #------------------------------------------------------------------2010--------------------------------------------------
#         if white_USA_df['vintage'][i]==2010:
#             if white_USA_df['appellation'][i]=='Napa Valley' or white_USA_df['appellation'][i]=='Santa Cruz Mountains' or white_USA_df['appellation'][i]=='Knights Valley':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2010].avgTempNapa
#             white_USA_df['avgTemp'+month][i]==2          
# #------------------------------------------------------------------2011--------------------------------------------------
#         elif white_USA_df['vintage'][i]==2011:
#             white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2011].avgTempNapa
# #------------------------------------------------------------------2012--------------------------------------------------
#         elif white_USA_df['vintage'][i]==2012:
#             white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2012].avgTempNapa
# #------------------------------------------------------------------2013--------------------------------------------------
#         elif white_USA_df['vintage'][i]==2013:
#             white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2013].avgTempNapa
# #------------------------------------------------------------------2014--------------------------------------------------
#         elif white_USA_df['vintage'][i]==2014:
#             white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2014].avgTempNapa
# #------------------------------------------------------------------2015--------------------------------------------------
#         elif white_USA_df['vintage'][i]==2015:
#             white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2015].avgTempNapa
# #------------------------------------------------------------------2016--------------------------------------------------
#         elif white_USA_df['vintage'][i]==2016:
#             if white_USA_df['appellation'][i]=='Napa Valley' or white_USA_df['appellation'][i]=='Santa Cruz Mountains' or white_USA_df['appellation'][i]=='Knights Valley':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2010].avgTempNapa
#             else:
#                 white_USA_df['avgTemp'+month][i]==111111111111
#         else:
#             white_USA_df['avgTemp'+month][i]=0
# # sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# # sorted_white_USA_df.head(50)
# white_USA_df.head(50)

# %%
# for month in calender_months:
#     white_USA_df['avgPrcp'+str(month)]=0

# for i in range(len(white_USA_df)):
#     for month in calender_months:           
#         if white_USA_df['vintage'][i]==2010:
#             white_USA_df['avgPrcp'+month][i]=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPSonoma
# #             print(white_USA_df)
#         else:
#             white_USA_df['avgPrcp'+month][i]=0
# sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# sorted_white_USA_df.head(1)

# %%
# for month in calender_months:
#     white_USA_df['avgPrcp'+str(month)]=0.00
# #     white_USA_df['avgPrcp'+str(month)].astype('float64')
#     white_USA_df['avgTemp'+str(month)]=0.00
# # print(white_USA_df.dtypes)
    
# # temporary_prcp=pd.DataFrame()
# temporary_prcp=[]
# for i in range(len(white_USA_df)):
#     for month in calender_months:           
#         if white_USA_df['vintage'][i]==2010:
#             temporary_prcp=prcp_df.loc[prcp_df['months']==month].loc[prcp_df['year']==2010].PRCPNapa
# #             temporary_prcp.astype("float64")
# #             temporary_prcp=np.format_float_scientific()
#             white_USA_df['avgPrcp'+str(month)][i]=temporary_prcp
#             white_USA_df['avgTemp'+str(month)][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2010].avgTempNapa
# #             white_USA_df['January'][i]=1
#         else:
#             white_USA_df['avgPrcp'+month][i]=0
# # print(white_USA_df.loc[white_USA_df['vintage']==2010].loc[white_USA_df['appellation']=='Napa Valley'].avgPrcpOctober)
# sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# sorted_white_USA_df.head(2)

# %%
# temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2010].avgTempNapa

# %%
# #Create empty columns to iterate through
# for month in calender_months:
#     white_USA_df['avgTemp'+str(month)]=0
# #Combine white wine with avgerage temperature and precipitation data
# for i, year in zip(range(len(white_USA_df)), calender_years):
#     for month in calender_months: 
# #------------------------------------------------------------------2016--------------------------------------------------
#         if white_USA_df['vintage'][i]==2016:
# #------------------------------------------------------------------California--------------------------------------------------
#             if white_USA_df['appellation'][i]=='Napa Valley' or white_USA_df['appellation'][i]=='Russian River Valley' or white_USA_df['appellation'][i]=='Knights Valley' or white_USA_df['appellation'][i]=='Carneros':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempNapa
#             if white_USA_df['appellation'][i]=='Santa Cruz Mountains':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempSanta
#             if white_USA_df['appellation'][i]=='Sonoma Coast':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempSonoma
# #------------------------------------------------------------------Washington--------------------------------------------------
#             if white_USA_df['appellation'][i]=='Yakima Valley' or white_USA_df['appellation'][i]=='Horse Heaven Hills' or white_USA_df['appellation'][i]=='Snipes Mountains' or white_USA_df['appellation'][i]=='Red Mountain':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempYakima
#             if white_USA_df['appellation'][i]=='Walla Walla Valley':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempWalla
#             if white_USA_df['appellation'][i]=='Columbia Valley':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempColumbia
# #------------------------------------------------------------------Oregon--------------------------------------------------
#             if white_USA_df['appellation'][i]=='Willamette Valley' or white_USA_df['appellation'][i]=='Dundee Hills' or white_USA_df['appellation'][i]=='Eola-Amity Hills' or white_USA_df['appellation'][i]=='Ribbon Ridge' or white_USA_df['appellation'][i]=='Chehalem Mountains':
#                 white_USA_df['avgTemp'+month][i]=temp_df.loc[temp_df['Months']==month].loc[temp_df['Year']==2016].avgTempDundee

#         else:
#             white_USA_df['avgTemp'+month][i]=0
# # sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# # sorted_white_USA_df.head(50)
# white_USA_df.head(50)

# %%
# data = {'Name': ['Ankit', 'Amit', 'Aishwarya', 'Priyanka'], 
#                 'Age': [21, 19, 20, 18], 
#                 'Stream': ['Math', 'Commerce', 'Arts', 'Biology'], 
#                 'Percentage': [88, 92, 95, 70]} 
  
# # Convert the dictionary into DataFrame 
# df = pd.DataFrame(data, columns = ['Name', 'Age', 'Stream', 'Percentage'])
# df['A']=0
# df
# Out:
#         Name  Age    Stream  Percentage  A
# 0      Ankit   21      Math          88  0
# 1       Amit   19  Commerce          92  0
# 2  Aishwarya   20      Arts          95  0
# 3   Priyanka   18   Biology          70  0

# %%
# for i in range(len(df)):
#     if df['Percentage'][i]==70:
#         df['Percentage'][i]=df.loc[df['Name']=='Aishwarya'].Age

# for i in range(len(df)):
#     if df['Percentage'][i]==20:
#         df['A'][i]=1
#     else:
#         df['A'][i]=0

# df
# Out:
#         Name  Age    Stream  Percentage  A
# 0      Ankit   21      Math          88  0
# 1       Amit   19  Commerce          92  0
# 2  Aishwarya   20      Arts          95  0
# 3   Priyanka   18   Biology          20  1

# %%
# print(bigdf.loc[bigdf['months']=='January'].loc[bigdf['year']==2010].avgMaxTempCA)
# print(bigdf.loc[bigdf['months']=='February'].loc[bigdf['year']==2010].avgMaxTempCA)
# print(bigdf.loc[bigdf['months']=='March'].loc[bigdf['year']==2010].avgMaxTempCA)
# print(bigdf.loc[bigdf['months']=='April'].loc[bigdf['year']==2010].avgMaxTempCA)
# print(bigdf.loc[bigdf['months']=='May'].loc[bigdf['year']==2010].avgMaxTempCA)
# print(bigdf.loc[bigdf['months']=='June'].loc[bigdf['year']==2010].avgMaxTempCA)
# print(bigdf.loc[bigdf['months']=='July'].loc[bigdf['year']==2010].avgMaxTempCA)
# print(bigdf.loc[bigdf['months']=='August'].loc[bigdf['year']==2010].avgMaxTempCA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0fee5dce9f96> in <module>
# ----> 1 print(bigdf.loc[bigdf['months']=='January'].loc[bigdf['year']==2010].avgMaxTempCA)
#       2 print(bigdf.loc[bigdf['months']=='February'].loc[bigdf['year']==2010].avgMaxTempCA)
#       3 print(bigdf.loc[bigdf['months']=='March'].loc[bigdf['year']==2010].avgMaxTempCA)
#       4 print(bigdf.loc[bigdf['months']=='April'].loc[bigdf['year']==2010].avgMaxTempCA)
#       5 print(bigdf.loc[bigdf['months']=='May'].loc[bigdf['year']==2010].avgMaxTempCA)
#
# NameError: name 'bigdf' is not defined

# %%
# # loc is label based: 1, 2, 100--- you get rows that have a 1 or 2 or 100
# # iloc is int based: 1, 2, 100---- you get the 1st, 2nd, 100th index
# # bigdf.loc[bigdf['months']=='January'].loc[bigdf['year']==2010].avgMaxTempCA
# x=[]
# for month in calender_months:
#     x.append(bigdf.loc[bigdf['months']==month].loc[bigdf['year']==2010].avgMaxTempCA)
# x

# %%
# #Where Method
# bigdf['avgMaxTempCA'].where(bigdf['months']=='January').where(bigdf['year']==2010)


# for i in range(len(white_USA_df)):
#     if white_USA_df['vintage'][i]==2010:
#         white_USA_df[month][i]==bigdf.loc[bigdf['year']==2010].loc[bigdf['months']==month].avgMaxTempCA
#     else:
#         white_USA_df[month][i]==0
# sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# sorted_white_USA_df.head(2)

# %%
# #Where Method
# # bigdf['avgMaxTempCA'].where(bigdf['months']=='January').where(bigdf['year']==2010)


# # for i in white_USA_df['vintage']:
# #     if i == 2010:
# #         white_USA_df['February']=bigdf['avgMaxTempCA'].where(bigdf['months']=='February').where(bigdf['year']==2010)
# #     else:
# #         white_USA_df['February']==0
# # white_USA_df
# # sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# # sorted_white_USA_df.head(2)


# for i in range(len(white_USA_df)):
#     if white_USA_df.loc[i, 'vintage']==2010:
#         white_USA_df.loc[i, 'January']==1
#     else:
#         white_USA_df.loc[i, 'January']==0
# sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# sorted_white_USA_df.head(2)

# %%
# for i in white_USA_df['vintage']:
#     for month in calender_months:
#         if i ==2010:
#             white_USA_df[month]=bigdf['avgMaxTempCA'].where(bigdf['months']==month).where(bigdf['year']==2010)
#         else:
#             white_USA_df[month]=0
# sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# sorted_white_USA_df.head(2)

# %%
# # sorted_white_USA_df=white_USA_df.sort_values(by=['vintage'], ascending=True)
# sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# sorted_white_USA_df.head(2)

# %%
# for i in range(len(white_USA_df)):
#     if white_USA_df['vintage'][i]==2010:
#         white_USA_df['January']=bigdf['avgMaxTempCA'].where(bigdf['months']=='January').where(bigdf['year']==2010)
#     else:
#         white_USA_df['January'][i]==0
# sorted_white_USA_df=white_USA_df[white_USA_df['vintage']==2010]
# sorted_white_USA_df.head(2)
        

# # white_USA_df['January']=bigdf['avgMaxTempCA'].where(bigdf['months']=='January').where(bigdf['year']==2010)
# # white_USA_df

# %%
# bigdf.loc[bigdf['months']==month].loc[bigdf['year']==2010].avgMaxTempCA

# %%
# bigdf['avgCA']=0
# for i in range(len(bigdf)):
#     bigdf['avgCA'][i]=(bigdf['avgMaxTempCA'][i]+bigdf['avgMinTempCA'][i])/2
# bigdf
